# %% [markdown]
# # PARSING DATA FROM A WEBSITE
#
# In this project, I scraped data from a car insurance website using BeautifulSoup. I will use this data for analysis and prediction to find out which cars should be marketed the most to attract more customers.
#
# For scraping data from this website, I'll perform the following tasks:
#
# [**Task 1**](#task1): Importing the libraries
#
# [**Task 2**](#task2): Creating the base url and choosing the header
#
# [**Task 3**](#task3): Extracting product links on the first page
#
# [**Task 4**](#task4): Extracting product links on all the pages
#
# [**Task 5**](#task5): Extracting information of the first product
#
# [**Task 6**](#task6): Extracting information of all the products

# %% [markdown]
# <a id='task1'></a>
# # Task 1: Importing the libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# <a id='task2'></a>
# # Task 2: Creating the base url and choosing the header

# %%
baseurl = 'https://www.theaa.com'

# %%
header = {
    'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.157 Safari/537.36"
}

# %% [markdown]
# <a id='task3'></a>
# # Task 3: Extracting product links on the first page

# %%
source = requests.get('https://www.theaa.com/used-cars/displaycars?sortby=closest&page=1&pricefrom=0&priceto=1000000&classid=102')# this get command returns a response object. And to get the source code from this response object we add .text. 
soup = BeautifulSoup(source.content, 'lxml')

# %%
productlist = soup.find_all('div', class_='vl-item')
print(productlist)
# Out:
# [<div class="vl-item clearfix">
# <h3 class="vl-title" title="MINI Clubman COOPER CLASSIC">
# <a class="black-link" href="/used-cars/cardetails/73-576234" rel="nofollow">
# <span class="make-model-text">MINI Clubman</span>
# <span>COOPER CLASSIC</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="vcarsdna" data-table-uid="576234" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/73-576234" rel="nofollow">
# <img alt="MINI Clubman COOPER CLASSIC" src="https://thumb.vcars.co.uk/vcarsdna/576234_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£17,950</strong>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2019</li>
# <li aria-hidden="true">•</li>
# <li>7,000 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Automatic</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/73-576234" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="MINI Cooper Convertible COOPER CLASSIC">
# <a class="black-link" href="/used-cars/cardetails/73-556699" rel="nofollow">
# <span class="make-model-text">MINI Cooper Convertible</span>
# <span>COOPER CLASSIC</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="vcarsdna" data-table-uid="556699" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/73-556699" rel="nofollow">
# <img alt="MINI Convertible COOPER CLASSIC" src="https://thumb.vcars.co.uk/vcarsdna/556699_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£16,750</strong>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2019</li>
# <li aria-hidden="true">•</li>
# <li>6,000 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Automatic</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/73-556699" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="Audi A1 SPORTBACK TFSI SPORT">
# <a class="black-link" href="/used-cars/cardetails/73-578180" rel="nofollow">
# <span class="make-model-text">Audi A1</span>
# <span>SPORTBACK TFSI SPORT</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="vcarsdna" data-table-uid="578180" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/73-578180" rel="nofollow">
# <img alt="Audi A1 SPORTBACK TFSI SPORT" src="https://thumb.vcars.co.uk/vcarsdna/578180_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£11,950</strong>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2017</li>
# <li aria-hidden="true">•</li>
# <li>25,000 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Manual</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/73-578180" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="BMW 1 Series 1.6 116i M Sport Sports Hatch (s/s) 5dr">
# <a class="black-link" href="/used-cars/cardetails/6-1775625" rel="nofollow">
# <span class="make-model-text">BMW 1 Series</span>
# <span>1.6 116i M Sport Sports Hatch (s/s) 5dr</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="autotrader" data-table-uid="1775625" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/6-1775625" rel="nofollow">
# <img alt="BMW 116 1.6 116i M Sport Sports Hatch (s/s) 5dr" src="https://thumb.vcars.co.uk/autotrader/1775625_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£8,795</strong>
# <span class="previous-price new-transport--light"> was £9,395</span>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2014</li>
# <li aria-hidden="true">•</li>
# <li>46,000 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Manual</li>
# </ul>
# <div class="finance-and-view">
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/6-1775625" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="BMW 1 Series 2.0 116i Sport 3dr">
# <a class="black-link" href="/used-cars/cardetails/6-1773922" rel="nofollow">
# <span class="make-model-text">BMW 1 Series</span>
# <span>2.0 116i Sport 3dr</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="autotrader" data-table-uid="1773922" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/6-1773922" rel="nofollow">
# <img alt="BMW 116 2.0 116i Sport 3dr" src="https://thumb.vcars.co.uk/autotrader/1773922_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£3,495</strong>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2010</li>
# <li aria-hidden="true">•</li>
# <li>85,000 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Manual</li>
# </ul>
# <div class="finance-and-view">
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/6-1773922" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="MINI Hatch 1.6 One (Sport Chili) 3dr">
# <a class="black-link" href="/used-cars/cardetails/6-1745145" rel="nofollow">
# <span class="make-model-text">MINI Hatch</span>
# <span>1.6 One (Sport Chili) 3dr</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="autotrader" data-table-uid="1745145" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/6-1745145" rel="nofollow">
# <img alt="MINI Hatch 1.6 One (Sport Chili) 3dr" loading="lazy" src="https://thumb.vcars.co.uk/autotrader/1745145_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£3,195</strong>
# <span class="previous-price new-transport--light"> was £3,895</span>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2013</li>
# <li aria-hidden="true">•</li>
# <li>95,000 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Manual</li>
# </ul>
# <div class="finance-and-view">
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/6-1745145" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="BMW 1 SERIES 120i SPORT">
# <a class="black-link" href="/used-cars/cardetails/73-429940" rel="nofollow">
# <span class="make-model-text">BMW 1 SERIES</span>
# <span>120i SPORT</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="vcarsdna" data-table-uid="429940" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/73-429940" rel="nofollow">
# <img alt="BMW 120 120i SPORT" loading="lazy" src="https://thumb.vcars.co.uk/vcarsdna/429940_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£15,250</strong>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# <div class="delivery">
# <img alt="Van icon" class="delivery-van" src="https://asset.vcars.co.uk/img/delivery-van-f16d119e67.svg"/><strong class="strong-inline">Delivery available</strong>
# </div>
# </div>
# <ul class="vl-specs">
# <li>2016</li>
# <li aria-hidden="true">•</li>
# <li>18,000 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Automatic</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/73-429940" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="Ford Fiesta 5Dr ST-Line X Edition 1.0 125PS Auto">
# <a class="black-link" href="/used-cars/cardetails/14-2553383" rel="nofollow">
# <span class="make-model-text">Ford Fiesta</span>
# <span>5Dr ST-Line X Edition 1.0 125PS Auto</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="gforce" data-table-uid="2553383" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/14-2553383" rel="nofollow">
# <img alt="Ford Fiesta 5Dr ST-Line X Edition 1.0 125PS Auto" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2553383_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£19,499</strong>
# <span class="previous-price new-transport--light"> was £21,000</span>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2020</li>
# <li aria-hidden="true">•</li>
# <li>2,383 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Automatic</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/14-2553383" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="Ford Fiesta 5Dr Titanium 1.0 Hybrid 125PS">
# <a class="black-link" href="/used-cars/cardetails/14-2585617" rel="nofollow">
# <span class="make-model-text">Ford Fiesta</span>
# <span>5Dr Titanium 1.0 Hybrid 125PS</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="gforce" data-table-uid="2585617" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/14-2585617" rel="nofollow">
# <img alt="Ford Fiesta 5Dr Titanium 1.0 Hybrid 125PS" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2585617_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£17,699</strong>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2020</li>
# <li aria-hidden="true">•</li>
# <li>598 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Manual</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/14-2585617" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="Ford Fiesta 5Dr ST-2 1.5 200PS">
# <a class="black-link" href="/used-cars/cardetails/14-2585614" rel="nofollow">
# <span class="make-model-text">Ford Fiesta</span>
# <span>5Dr ST-2 1.5 200PS</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="gforce" data-table-uid="2585614" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/14-2585614" rel="nofollow">
# <img alt="Ford Fiesta 5Dr ST-2 1.5 200PS" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2585614_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£17,499</strong>
# <span class="previous-price new-transport--light"> was £18,000</span>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2019</li>
# <li aria-hidden="true">•</li>
# <li>6,349 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Manual</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/14-2585614" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="Ford Fiesta 5Dr Titanium 1.0 Hybrid 125PS">
# <a class="black-link" href="/used-cars/cardetails/14-2554709" rel="nofollow">
# <span class="make-model-text">Ford Fiesta</span>
# <span>5Dr Titanium 1.0 Hybrid 125PS</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="gforce" data-table-uid="2554709" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/14-2554709" rel="nofollow">
# <img alt="Ford Fiesta 5Dr Titanium 1.0 Hybrid 125PS" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2554709_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£16,499</strong>
# <span class="previous-price new-transport--light"> was £18,000</span>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2020</li>
# <li aria-hidden="true">•</li>
# <li>3,256 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Manual</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/14-2554709" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="Ford Fiesta 5Dr ST-Line Edition 1.0 Hybrid 125PS">
# <a class="black-link" href="/used-cars/cardetails/14-2561657" rel="nofollow">
# <span class="make-model-text">Ford Fiesta</span>
# <span>5Dr ST-Line Edition 1.0 Hybrid 125PS</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="gforce" data-table-uid="2561657" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/14-2561657" rel="nofollow">
# <img alt="Ford Fiesta 5Dr ST-Line Edition 1.0 Hybrid 125PS" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2561657_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£16,499</strong>
# <span class="previous-price new-transport--light"> was £17,499</span>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2020</li>
# <li aria-hidden="true">•</li>
# <li>7 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Manual</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/14-2561657" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="Ford Fiesta Vignale Fiesta 5Dr Vignale 1.0 140PS">
# <a class="black-link" href="/used-cars/cardetails/14-2598037" rel="nofollow">
# <span class="make-model-text">Ford Fiesta Vignale</span>
# <span>Fiesta 5Dr Vignale 1.0 140PS</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="gforce" data-table-uid="2598037" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/14-2598037" rel="nofollow">
# <img alt="Ford Fiesta Fiesta 5Dr Vignale 1.0 140PS" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2598037_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£15,999</strong>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2019</li>
# <li aria-hidden="true">•</li>
# <li>5,886 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Manual</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/14-2598037" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="Ford Fiesta Vignale Fiesta 5Dr Vignale Edition 1.0 125PS">
# <a class="black-link" href="/used-cars/cardetails/14-2598723" rel="nofollow">
# <span class="make-model-text">Ford Fiesta Vignale</span>
# <span>Fiesta 5Dr Vignale Edition 1.0 125PS</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="gforce" data-table-uid="2598723" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/14-2598723" rel="nofollow">
# <img alt="Ford Fiesta Fiesta 5Dr Vignale Edition 1.0 125PS" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2598723_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£14,799</strong>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2018</li>
# <li aria-hidden="true">•</li>
# <li>5,801 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Manual</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/14-2598723" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="Ford Fiesta 5Dr Active X 1.0 100PS">
# <a class="black-link" href="/used-cars/cardetails/14-2598725" rel="nofollow">
# <span class="make-model-text">Ford Fiesta</span>
# <span>5Dr Active X 1.0 100PS</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="gforce" data-table-uid="2598725" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/14-2598725" rel="nofollow">
# <img alt="Ford Fiesta 5Dr Active X 1.0 100PS" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2598725_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£14,299</strong>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2019</li>
# <li aria-hidden="true">•</li>
# <li>10,872 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Manual</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/14-2598725" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="Ford Fiesta 5Dr ST-Line X 1.0 125PS">
# <a class="black-link" href="/used-cars/cardetails/14-2596960" rel="nofollow">
# <span class="make-model-text">Ford Fiesta</span>
# <span>5Dr ST-Line X 1.0 125PS</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="gforce" data-table-uid="2596960" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/14-2596960" rel="nofollow">
# <img alt="Ford Fiesta 5Dr ST-Line X 1.0 125PS" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2596960_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£14,000</strong>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2019</li>
# <li aria-hidden="true">•</li>
# <li>12,981 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Manual</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/14-2596960" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="Ford Fiesta 5Dr ST-Line 1.0 125PS">
# <a class="black-link" href="/used-cars/cardetails/14-2575853" rel="nofollow">
# <span class="make-model-text">Ford Fiesta</span>
# <span>5Dr ST-Line 1.0 125PS</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="gforce" data-table-uid="2575853" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/14-2575853" rel="nofollow">
# <img alt="Ford Fiesta 5Dr ST-Line 1.0 125PS" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2575853_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£13,499</strong>
# <span class="previous-price new-transport--light"> was £14,199</span>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2020</li>
# <li aria-hidden="true">•</li>
# <li>5,742 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Manual</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/14-2575853" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="Ford Fiesta 5Dr ST-Line X 1.0 125PS">
# <a class="black-link" href="/used-cars/cardetails/14-2570428" rel="nofollow">
# <span class="make-model-text">Ford Fiesta</span>
# <span>5Dr ST-Line X 1.0 125PS</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="gforce" data-table-uid="2570428" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/14-2570428" rel="nofollow">
# <img alt="Ford Fiesta 5Dr ST-Line X 1.0 125PS" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2570428_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£13,399</strong>
# <span class="previous-price new-transport--light"> was £13,799</span>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2019</li>
# <li aria-hidden="true">•</li>
# <li>8,614 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Manual</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/14-2570428" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="Ford Fiesta 5Dr Active X 1.0 125PS">
# <a class="black-link" href="/used-cars/cardetails/14-2576361" rel="nofollow">
# <span class="make-model-text">Ford Fiesta</span>
# <span>5Dr Active X 1.0 125PS</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="gforce" data-table-uid="2576361" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/14-2576361" rel="nofollow">
# <img alt="Ford Fiesta 5Dr Active X 1.0 125PS" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2576361_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£13,000</strong>
# <span class="previous-price new-transport--light"> was £14,299</span>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2018</li>
# <li aria-hidden="true">•</li>
# <li>7,432 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Manual</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/14-2576361" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>, <div class="vl-item clearfix">
# <h3 class="vl-title" title="Ford Fiesta 5Dr Titanium 1.0 100PS">
# <a class="black-link" href="/used-cars/cardetails/14-2575852" rel="nofollow">
# <span class="make-model-text">Ford Fiesta</span>
# <span>5Dr Titanium 1.0 100PS</span>
# </a>
# </h3>
# <button class="shortlist-btn" data-table-name="gforce" data-table-uid="2575852" title="Click to add this vehicle to your shortlist" type="button">
# </button>
# <div class="two-column">
# <a class="image-link" href="/used-cars/cardetails/14-2575852" rel="nofollow">
# <img alt="Ford Fiesta 5Dr Titanium 1.0 100PS" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2575852_1.jpg"/>
# </a>
# <div class="right-column">
# <div class="vl-price">
# <strong class="total-price strong-inline new-transport--bold">£11,899</strong>
# <span class="previous-price new-transport--light"> was £12,399</span>
# </div>
# <div class="clearfix">
# <div class="vl-location"><span class="icon-location"></span><strong class="strong-inline">Enfield</strong></div>
# </div>
# <ul class="vl-specs">
# <li>2019</li>
# <li aria-hidden="true">•</li>
# <li>7,522 miles</li>
# <li aria-hidden="true">•</li>
# <li>Petrol</li>
# <li aria-hidden="true">•</li>
# <li>Manual</li>
# </ul>
# <div class="finance-and-view">
# <div class="finance-eligible">
# <img alt="AA Car Finance" src="https://asset.vcars.co.uk/img/yellow-sq-aa-logo-bed2b1a89a.svg"/><span class="new-transport--regular">Car Finance</span>
# </div>
# <a class="btn btn-full btn-primary view-details-btn" href="/used-cars/cardetails/14-2575852" rel="nofollow">
#                    View
#                </a>
# </div>
# </div>
# </div>
# </div>]

# %% [markdown]
# Creating a for loop to get the links of cars so that I can access information about each car at a later stage.

# %%
productlinks= []
for item in productlist:
    for link in item.find_all('a', href = True, class_ = 'black-link'):
        print(link['href'])
# Out:
# /used-cars/cardetails/73-576234
# /used-cars/cardetails/73-556699
# /used-cars/cardetails/73-578180
# /used-cars/cardetails/6-1775625
# /used-cars/cardetails/6-1773922
# /used-cars/cardetails/6-1745145
# /used-cars/cardetails/73-429940
# /used-cars/cardetails/14-2553383
# /used-cars/cardetails/14-2585617
# /used-cars/cardetails/14-2585614
# /used-cars/cardetails/14-2554709
# /used-cars/cardetails/14-2561657
# /used-cars/cardetails/14-2598037
# /used-cars/cardetails/14-2598723
# /used-cars/cardetails/14-2598725
# /used-cars/cardetails/14-2596960
# /used-cars/cardetails/14-2575853
# /used-cars/cardetails/14-2570428
# /used-cars/cardetails/14-2576361
# /used-cars/cardetails/14-2575852

# %% [markdown]
# Concatenating the base url with the car links to form the complete url to access each page

# %%
for item in productlist:
    for link in item.find_all('a', href = True, class_='black-link'):
        productlinks.append(baseurl + link['href'])
print((productlinks))
# Out:
# ['https://www.theaa.com/used-cars/cardetails/73-576234', 'https://www.theaa.com/used-cars/cardetails/73-556699', 'https://www.theaa.com/used-cars/cardetails/73-578180', 'https://www.theaa.com/used-cars/cardetails/6-1775625', 'https://www.theaa.com/used-cars/cardetails/6-1773922', 'https://www.theaa.com/used-cars/cardetails/6-1745145', 'https://www.theaa.com/used-cars/cardetails/73-429940', 'https://www.theaa.com/used-cars/cardetails/14-2553383', 'https://www.theaa.com/used-cars/cardetails/14-2585617', 'https://www.theaa.com/used-cars/cardetails/14-2585614', 'https://www.theaa.com/used-cars/cardetails/14-2554709', 'https://www.theaa.com/used-cars/cardetails/14-2561657', 'https://www.theaa.com/used-cars/cardetails/14-2598037', 'https://www.theaa.com/used-cars/cardetails/14-2598723', 'https://www.theaa.com/used-cars/cardetails/14-2598725', 'https://www.theaa.com/used-cars/cardetails/14-2596960', 'https://www.theaa.com/used-cars/cardetails/14-2575853', 'https://www.theaa.com/used-cars/cardetails/14-2570428', 'https://www.theaa.com/used-cars/cardetails/14-2576361', 'https://www.theaa.com/used-cars/cardetails/14-2575852']

# %% [markdown]
# <a id='task4'></a>
# # Task 4: Extracting product links on all the pages

# %% [markdown]
# Since there are 20 cars per page and I want all the cars, so I am using a for loop to get information of cars from all the pages.

# %%
productlinks = []
for i in range(1,20):
    source = requests.get(f'https://www.theaa.com/used-cars/displaycars?sortby=closest&page={i}&pricefrom=0&priceto=1000000&classid=102')
    soup = BeautifulSoup(source.content, 'lxml')
    productlist = soup.find_all('div', class_='vl-item')
    for item in productlist:
        for link in item.find_all('a', href = True, class_='black-link'):
            productlinks.append(baseurl + link['href'])
print((productlinks))
# Out:
# ['https://www.theaa.com/used-cars/cardetails/73-576234', 'https://www.theaa.com/used-cars/cardetails/73-556699', 'https://www.theaa.com/used-cars/cardetails/73-578180', 'https://www.theaa.com/used-cars/cardetails/6-1775625', 'https://www.theaa.com/used-cars/cardetails/6-1773922', 'https://www.theaa.com/used-cars/cardetails/6-1745145', 'https://www.theaa.com/used-cars/cardetails/73-429940', 'https://www.theaa.com/used-cars/cardetails/14-2553383', 'https://www.theaa.com/used-cars/cardetails/14-2585617', 'https://www.theaa.com/used-cars/cardetails/14-2585614', 'https://www.theaa.com/used-cars/cardetails/14-2554709', 'https://www.theaa.com/used-cars/cardetails/14-2561657', 'https://www.theaa.com/used-cars/cardetails/14-2598037', 'https://www.theaa.com/used-cars/cardetails/14-2598723', 'https://www.theaa.com/used-cars/cardetails/14-2598725', 'https://www.theaa.com/used-cars/cardetails/14-2596960', 'https://www.theaa.com/used-cars/cardetails/14-2575853', 'https://www.theaa.com/used-cars/cardetails/14-2570428', 'https://www.theaa.com/used-cars/cardetails/14-2576361', 'https://www.theaa.com/used-cars/cardetails/14-2575852', 'https://www.theaa.com/used-cars/cardetails/14-2556661', 'https://www.theaa.com/used-cars/cardetails/14-2566871', 'https://www.theaa.com/used-cars/cardetails/14-2591882', 'https://www.theaa.com/used-cars/cardetails/14-2591881', 'https://www.theaa.com/used-cars/cardetails/14-2591883', 'https://www.theaa.com/used-cars/cardetails/14-2594132', 'https://www.theaa.com/used-cars/cardetails/14-2598729', 'https://www.theaa.com/used-cars/cardetails/14-2598035', 'https://www.theaa.com/used-cars/cardetails/14-2588009', 'https://www.theaa.com/used-cars/cardetails/14-2588008', 'https://www.theaa.com/used-cars/cardetails/14-2598036', 'https://www.theaa.com/used-cars/cardetails/14-2580737', 'https://www.theaa.com/used-cars/cardetails/14-2588372', 'https://www.theaa.com/used-cars/cardetails/137-581812', 'https://www.theaa.com/used-cars/cardetails/137-475945', 'https://www.theaa.com/used-cars/cardetails/137-519278', 'https://www.theaa.com/used-cars/cardetails/137-575830', 'https://www.theaa.com/used-cars/cardetails/137-575820', 'https://www.theaa.com/used-cars/cardetails/137-575821', 'https://www.theaa.com/used-cars/cardetails/137-575822', 'https://www.theaa.com/used-cars/cardetails/137-575826', 'https://www.theaa.com/used-cars/cardetails/137-455433', 'https://www.theaa.com/used-cars/cardetails/137-511996', 'https://www.theaa.com/used-cars/cardetails/137-575823', 'https://www.theaa.com/used-cars/cardetails/137-575824', 'https://www.theaa.com/used-cars/cardetails/137-575825', 'https://www.theaa.com/used-cars/cardetails/137-575827', 'https://www.theaa.com/used-cars/cardetails/137-575828', 'https://www.theaa.com/used-cars/cardetails/137-575829', 'https://www.theaa.com/used-cars/cardetails/137-307671', 'https://www.theaa.com/used-cars/cardetails/137-307672', 'https://www.theaa.com/used-cars/cardetails/137-370843', 'https://www.theaa.com/used-cars/cardetails/137-526578', 'https://www.theaa.com/used-cars/cardetails/137-526579', 'https://www.theaa.com/used-cars/cardetails/137-575815', 'https://www.theaa.com/used-cars/cardetails/137-575816', 'https://www.theaa.com/used-cars/cardetails/137-575817', 'https://www.theaa.com/used-cars/cardetails/137-575818', 'https://www.theaa.com/used-cars/cardetails/137-417828', 'https://www.theaa.com/used-cars/cardetails/137-417829', 'https://www.theaa.com/used-cars/cardetails/137-425467', 'https://www.theaa.com/used-cars/cardetails/137-425468', 'https://www.theaa.com/used-cars/cardetails/137-511995', 'https://www.theaa.com/used-cars/cardetails/137-575842', 'https://www.theaa.com/used-cars/cardetails/137-575814', 'https://www.theaa.com/used-cars/cardetails/137-575780', 'https://www.theaa.com/used-cars/cardetails/137-458133', 'https://www.theaa.com/used-cars/cardetails/137-526577', 'https://www.theaa.com/used-cars/cardetails/137-511994', 'https://www.theaa.com/used-cars/cardetails/137-575778', 'https://www.the ...

# %% [markdown]
# <a id='task5'></a>
# # Task 5: Extracting information of the first product

# %% [markdown]
# Let's try to get information for each product now. We'll start with a test link and then loop all the items.

# %%
testlink= 'https://www.theaa.com/used-cars/cardetails/14-2556661'
r = requests.get(testlink, headers = header)
soup = BeautifulSoup(r.content, 'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en-GB">
# <head>
# <meta charset="utf-8"/>
# <title>Used Ford Fiesta for Sale | AA Cars</title>
# <meta content="" name="description"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="#ffcc00" name="theme-color"/>
# <link href="https://www.theaa.com/Assets/images/favicon.png" rel="shortcut icon" type="image/x-icon"/>
# <meta content="Ford Fiesta 5Dr Titanium 1.0 100PS" property="og:title"/>
# <meta content="product" property="og:type"/>
# <meta content="https://www.theaa.com/used-cars/cardetails/14-2556661" property="og:url"/>
# <meta content="https://thumb.vcars.co.uk/gforce/2556661_1.jpg" property="og:image"/>
# <style>html{font-family:sans-serif;line-height:1.15;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}article,aside,footer,header,nav,section{display:block}h1{font-size:2em;margin:.67em 0}figcaption,figure,main{display:block}figure{margin:1em 40px}hr{box-sizing:content-box;height:0;overflow:visible}pre{font-family:monospace,monospace;font-size:1em}a{background-color:transparent;-webkit-text-decoration-skip:objects}a:active,a:hover{outline-width:0}abbr[title]{border-bottom:none;text-decoration:underline;text-decoration:underline dotted}b,strong{font-weight:inherit}b,strong{font-weight:bolder}code,kbd,samp{font-family:monospace,monospace;font-size:1em}dfn{font-style:italic}mark{background-color:#ff0;color:#000}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-.25em}sup{top:-.5em}audio,video{display:inline-block}audio:not([controls]){display:none;height:0}img{border-style:none}svg:not(:root){overflow:hidden}button,input,optgroup,select,textarea{font-family:sans-serif;font-size:100%;line-height:1.15;margin:0}button,input{overflow:visible}button,select{text-transform:none}[type=reset],[type=submit],button,html [type=button]{-webkit-appearance:button}[type=button]::-moz-focus-inner,[type=reset]::-moz-focus-inner,[type=submit]::-moz-focus-inner,button::-moz-focus-inner{border-style:none;padding:0}[type=button]:-moz-focusring,[type=reset]:-moz-focusring,[type=submit]:-moz-focusring,button:-moz-focusring{outline:1px dotted ButtonText}fieldset{border:1px solid silver;margin:0 2px;padding:.35em .625em .75em}legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal}progress{display:inline-block;vertical-align:baseline}textarea{overflow:auto}[type=checkbox],[type=radio]{box-sizing:border-box;padding:0}[type=number]::-webkit-inner-spin-button,[type=number]::-webkit-outer-spin-button{height:auto}[type=search]{-webkit-appearance:textfield;outline-offset:-2px}[type=search]::-webkit-search-cancel-button,[type=search]::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}details,menu{display:block}summary{display:list-item}canvas{display:inline-block}template{display:none}[hidden]{display:none}.col-xs-1{width:8.33333%}.offset-xs-1{margin-left:8.33333%}.rm-offset-xs{margin-left:0}.col-xs-2{width:16.66667%}.offset-xs-2{margin-left:16.66667%}.rm-offset-xs{margin-left:0}.col-xs-3{width:25%}.offset-xs-3{margin-left:25%}.rm-offset-xs{margin-left:0}.col-xs-4{width:33.33333%}.offset-xs-4{margin-left:33.33333%}.rm-offset-xs{margin-left:0}.col-xs-5{width:41.66667%}.offset-xs-5{margin-left:41.66667%}.rm-offset-xs{margin-left:0}.col-xs-6{width:50%}.offset-xs-6{margin-left:50%}.rm-offset-xs{margin-left:0}.col-xs-7{width:58.33333%}.offset-xs-7{margin-left:58.33333%}.rm-offset-xs{margin-left:0}.col-xs-8{width:66.66667%}.offset-xs-8{margin-left:66.66667%}.rm-offset-xs{margin-left:0}.col-xs-9{width:75%}.offset-xs-9{margin-left:75%}.rm-offset-xs{margin-left:0}.col-xs-10{width:83.33333%}.offset-xs-10{margin-left:83.33333%}.rm-offset-xs{margin-left:0}.col-xs-11{width:91.66667%}.offset-xs-11{margin-left:91.66667%}.rm-offset-xs{margin-left:0}.col-xs-12{width:100%}.offset-xs-12{margin-left:100%}.rm-offset-xs{margin-left:0}.clearfix:after,.consent-agreement:after,.container-full:after,.container-white:after,.container:after,.floating-panel:after,.footer-links:after,.gdpr-contacts .consent-agreement-item .consent-agreement-item-choice:after,.header-wrapper:after,.link-group:after,.long-text-link-group:after,.main-navigation:after,.panel:after,.popular-links:after,.related-links:after,.row:after,.sign-in-form-submit:after,.white-bg-border-top:after,.white-bg:after,.white-full-border-btm:after,[class*=" col-"]:after,[class^=col-]:after{content:'';display:table;clear:both}html{box-sizing:border-box;-moz-box-sizing:border-box;-webkit-box-sizing:border-box}*,:after,:before{box-sizing:inheri ...
# </style>
# <meta content="noindex, nofollow" name="robots"/>
# <script>
#             (function (i, s, o, g, r, a, m) {
#                 i['GoogleAnalyticsObject'] = r;
#                 i[r] = i[r] || function () {
#                         (i[r].q = i[r].q || []).push(arguments)
#                     }, i[r].l = 1 * new Date();
#                 a = s.createElement(o),
#                     m = s.getElementsByTagName(o)[0];
#                 a.async = 1;
#                 a.src = g;
#                 m.parentNode.insertBefore(a, m)
#             })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#                             ga('create', 'UA-186834-3', 'auto');
#                                 ga('send', 'pageview');
#                         </script>
# <script>
#                 !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#                     n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#                     n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#                     t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#                     document,'script','https://connect.facebook.net/en_US/fbevents.js');
#
#                 fbq('init', '1328416857183380');
#                 fbq('track', "PageView");
#             </script>
# <!--[if IE 9]>
#             <style>
#                 .styled-select:after{display:none;}.styled-select select{padding-right:8px;}
#             </style>
#             <![endif]-->
# </head>
# <body>
# <script>
#             (function(a,b,c,d){
#             a='//tags.tiqcdn.com/utag/theaa/vcars/prod/utag.js';
#             b=document;c='script';d=b.createElement(c);d.src=a;d.type='text/java'+c;d.async=true;
#             a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);
#             })();
#         </script>
# <div class="outer-wrap" id="header">
# <div class="site-header">
# <div class="logo-wrapper">
# <div class="logo-mask">
# <div class="figure-wrapper">
# <figure class="site-header-logo">
# <a href="/cars/" title="The AA | Cars">
# <img alt="The AA" height="212" loading="lazy" src="https://asset.vcars.co.uk/img/logo-1f70a4d2b9.png" width="438"/>
# </a>
# </figure>
# </div>
# </div>
# </div>
# <div class="header-wrapper">
# <div class="mobile-menu-btns">
# <button class="menu-toggle js-toggle-menu">Menu <span class="icon-down-open"></span></button>
# </div>
# <div id="basket-container">
# <button class="js-toggle-recently-viewed recent-btn"><span class="show-tablet">Recently viewed</span><span class="waiting" id="js-car-total"></span></button>
# </div>
# </div>
# </div>
# <div class="recently-viewed-cars-list"></div>
# <div class="menu-container">
# <nav class="main-navigation">
# <ul class="top-menu clearfix">
# <li>
# <a class="has-submenu js-toggle-submenu top-level" href="#">Used Cars <span class="icon-menu-item"></span></a>
# <nav class="sub-menu-container">
# <a class="menu-item--back" href="#"><span class="icon-menu-back"></span> Used Cars</a>
# <ul class="sub-menu">
# <li>
# <a class="has-submenu category" href="#">Browse by Manufacturer</a>
# <nav class="extended-menu menu-manufacturer">
# <a class="menu-item--back" href="#"><span class="icon-menu-back"></span> Browse by Manufacturer</a>
# <div class="extended-menu--section">
# <ul>
# <li><a href="/used-cars/used-audi">Used Audi</a></li>
# <li><a href="/used-cars/used-bmw">Used BMW</a></li>
# <li><a href="/used-cars/used-citroen">Used Citroen</a></li>
# <li><a href="/used-cars/used-fiat">Used Fiat</a></li>
# <li><a href="/used-cars/used-ford">Used Ford</a></li>
# <li><a href="/used-cars/used-honda">Used Honda</a></li>
# <li><a href="/used-cars/used-hyundai">Used Hyundai</a></li>
# <li><a href="/used-cars/used-jaguar">Used Jaguar</a></li>
# <li><a href="/used-cars/used-kia">Used Kia</a></li>
# <li><a href="/used-cars/used-land_rover">Used Land Rover</a></li>
# <li><a href="/used-cars/used-mini">Used MINI</a></li>
# <li><a href="/used-cars/used-mazda">Used Mazda</a></li>
# <li><a href="/used-cars/used-mercedes">Used Mercedes</a></li>
# <li><a href="/used-cars/used-nissan">Used Nissan</a></li>
# <li><a href="/used-cars/used-peugeot">Used Peugeot</a></li>
# <li><a href="/used-cars/used-renault">Used Renault</a></li>
# <li><a href="/used-cars/used-toyota">Used Toyota</a></li>
# <li><a href="/used-cars/used-vauxhall">Used Vauxhall</a></li>
# <li><a href="/used-cars/used-volkswagen">Used Volkswagen</a></li>
# <li><a href="/used-cars/used-volvo">Used Volvo</a></li>
# <li><a href="/used-cars/">Search All Used Cars</a></li>
# </ul>
# </div>
# </nav>
# </li>
# <li>
# <a class="has-submenu category" href="#">Browse by Model</a>
# <nav class="extended-menu menu-model">
# <a class="menu-item--back" href="#"><span class="icon-menu-back"></span> Browse by Model</a>
# <div class="extended-menu--section">
# <ul>
# <li><a href="/used-cars/used-audi-a3">Used Audi A3</a></li>
# <li><a href="/used-cars/used-fiat-500">Used Fiat 500</a></li>
# <li><a href="/used-cars/used-ford-fiesta">Used Ford Fiesta</a></li>
# <li><a href="/used-cars/used-ford-focus">Used Ford Focus</a></li>
# <li><a href="/used-cars/used-ford-kuga">Used Ford Kuga</a></li>
# <li><a href="/used-cars/used-honda-civic">Used Honda Civic</a></li>
# <li><a href="/used-cars/used-kia-sportage">Used Kia Sportage</a></li>
# <li><a href="/used-cars/used-mercedes-a_class">Used Mercedes A Class</a></li>
# <li><a href="/used-cars/used-mercedes-c_class">Used Mercedes C Class</a></li>
# <li><a href="/used-cars/used-mercedes-e_class">Used Mercedes E Class</a></li>
# <li><a href="/used-cars/used-nissan-juke">Used Nissan Juke</a></li>
# <li><a href="/used-cars/used-nissan-qashqai">Used Nissan Qashqai</a></li>
# <li><a href="/used-cars/used-renault-clio">Used Renault Clio</a></li>
# <li><a href="/used-cars/used-toyota-yaris">Used Toyota Yaris</a></li>
# <li><a href="/used-cars/used-vauxhall-astra">Used Vauxhall Astra</a></li>
# <li><a href="/used-cars/used-vauxhall-corsa">Used Vauxhall Corsa</a></li>
# <li><a href="/used-cars/used-vauxhall-insignia">Used Vauxhall Insignia</a></li>
# <li><a href="/used-cars/used-vauxhall-mokka">Used Vauxhall Mokka</a></li>
# <li><a href="/used-cars/used-volkswagen-golf">Used Volkswagen Golf</a></li>
# <li><a href="/used-cars/used-volkswagen-polo">Used Volkswagen Polo</a></li>
# <li><a href="/used-cars/">Search All Used Cars</a></li>
# </ul>
# </div>
# </nav>
# </li>
# <li>
# <a class="has-submenu category" href="#">Browse by Location</a>
# <nav class="extended-menu menu-location">
# <a class="menu-item--back" href="#"><span class="icon-menu-back"></span> Browse by Location</a>
# <div class="extended-menu--section">
# <ul>
# <li><a href="/used-cars/local/west_midlands/birmingham">Used Cars in Birmingham</a></li>
# <li><a href="/used-cars/local/east_sussex/brighton">Used Cars in Brighton</a></li>
# <li><a href="/used-cars/local/bristol">Used Cars in Bristol</a></li>
# <li><a href="/used-cars/local/wales/cardiff">Used Cars in Cardiff</a></li>
# <li><a href="/used-cars/local/west_midlands/coventry">Used Cars in Coventry</a></li>
# <li><a href="/used-cars/local/greater_london/croydon">Used Cars in Croydon</a></li>
# <li><a href="/used-cars/local/scotland/edinburgh">Used Cars in Edinburgh</a></li>
# <li><a href="/used-cars/local/scotland/glasgow">Used Cars in Glasgow</a></li>
# <li><a href="/used-cars/local/west_yorkshire/leeds">Used Cars in Leeds</a></li>
# <li><a href="/used-cars/local/leicestershire/leicester">Used Cars in Leicester</a></li>
# <li><a href="/used-cars/local/merseyside/liverpool">Used Cars in Liverpool</a></li>
# <li><a href="/used-cars/local/greater_london">Used Cars in London</a></li>
# <li><a href="/used-cars/local/greater_manchester">Used Cars in Manchester</a></li>
# <li><a href="/used-cars/local/tyne_and_wear/newcastle-upon-tyne">Used Cars in Newcastle upon Tyne</a></li>
# <li><a href="/used-cars/local/northamptonshire/northampton">Used Cars in Northampton</a></li>
# <li><a href="/used-cars/local/norfolk/norwich">Used Cars in Norwich</a></li>
# <li><a href="/used-cars/local/nottinghamshire/nottingham">Used Cars in Nottingham</a></li>
# <li><a href="/used-cars/local/south_yorkshire/sheffield">Used Cars in Sheffield</a></li>
# <li><a href="/used-cars/local/hampshire/southampton">Used Cars in Southampton</a></li>
# <li><a href="/used-cars/local/staffordshire/stoke-on-trent">Used Cars in Stoke-on-Trent</a></li>
# <li><a href="/used-cars/local">All Locations</a></li>
# </ul>
# </div>
# </nav>
# </li>
# <li>
# <a class="has-submenu category" href="#">Browse by Bodystyle</a>
# <nav class="extended-menu menu-bodystyle">
# <a class="menu-item--back" href="#"><span class="icon-menu-back"></span> Browse by Bodystyle</a>
# <div class="extended-menu--section">
# <ul>
# <li><a href="/used-cars/4x4-for-sale">Used 4x4</a></li>
# <li><a href="/used-cars/suv-for-sale">Used SUVs</a></li>
# <li><a href="/used-cars/executive-car-for-sale">Used Executive Cars</a></li>
# <li><a href="/used-cars/family-car-for-sale">Used Family Cars</a></li>
# <li><a href="/used-cars/luxury-car-for-sale">Used Luxury Cars</a></li>
# <li><a href="/used-cars/microcar-for-sale">Used Microcars</a></li>
# <li><a href="/used-cars/people-carrier-for-sale">Used People Carriers</a></li>
# <li><a href="/used-cars/sports-car-for-sale">Used Sports Cars</a></li>
# <li><a href="/used-cars/supercar-for-sale">Used Supercars</a></li>
# <li><a href="/used-cars/supermini-for-sale">Used Superminis</a></li>
# <li><a href="/used-cars/bodystyle/hatchback">Used Hatchbacks</a></li>
# <li><a href="/used-cars/bodystyle/estate">Used Estates</a></li>
# <li><a href="/used-cars/bodystyle/saloon">Used Saloons</a></li>
# <li><a href="/used-cars/bodystyle/coupe">Used Coupes</a></li>
# <li><a href="/used-cars/bodystyle/convertible">Used Convertibles</a></li>
# </ul>
# </div>
# </nav>
# </li>
# <li>
# <a class="has-submenu category" href="#">Browse by Fuel Type</a>
# <nav class="extended-menu menu-fuel type">
# <a class="menu-item--back" href="#"><span class="icon-menu-back"></span> Browse by Fuel Type</a>
# <div class="extended-menu--section">
# <ul>
# <li><a href="/used-cars/diesel">Used Diesel Cars</a></li>
# <li><a href="/used-cars/electric">Used Electric Cars</a></li>
# <li><a href="/used-cars/hybrid">Used Hybrid Cars</a></li>
# <li><a href="/used-cars/petrol">Used Petrol Cars</a></li>
# </ul>
# </div>
# </nav>
# </li>
# <li>
# <a class="has-submenu category" href="#">Browse by Transmission</a>
# <nav class="extended-menu menu-transmission">
# <a class="menu-item--back" href="#"><span class="icon-menu-back"></span> Browse by Transmission</a>
# <div class="extended-menu--section">
# <ul>
# <li><a href="/used-cars/automatic">Used Automatic Cars</a></li>
# <li><a href="/used-cars/manual">Used Manual Cars</a></li>
# </ul>
# </div>
# </nav>
# </li>
# </ul>
# </nav>
# </li>
# <li>
# <a class="top-level" href="/used-vans/">Used Vans </a>
# </li>
# <li>
# <a class="has-submenu js-toggle-finance top-level" href="#">Finance <span class="icon-menu-item"></span></a>
# <nav class="menu-links">
# <a class="menu-item--back" href="#"><span class="icon-menu-back"></span> Finance</a>
# <ul>
# <li><a href="/cars/finance">Car finance</a></li>
# <li><a href="/cars/finance/eligibility-check">Eligibility checker</a></li>
# <li><a href="/cars/finance/car-finance-calculator">Car finance calculator</a></li>
# <li><a href="/cars/finance/faqs">FAQs</a></li>
# <li><a href="/cars/finance/car-finance-explained">Car finance explained</a></li>
# </ul>
# </nav>
# </li>
# <li>
# <a class="has-submenu js-toggle-finance top-level" href="#">Warranty <span class="icon-menu-item"></span></a>
# <nav class="menu-links">
# <a class="menu-item--back" href="#"><span class="icon-menu-back"></span> Warranty</a>
# <ul>
# <li><a href="/cars/warranty">Warranty</a></li>
# <li><a href="/cars/warranty/products">Our warranties</a></li>
# <li><a href="/cars/warranty/faqs">FAQs</a></li>
# <li><a href="/cars/warranty/contact-us">Contact us</a></li>
# </ul>
# </nav>
# </li>
# <li>
# <a class="top-level" href="/used-cars/valuation">Value my car </a>
# </li>
# <li>
# <a class="top-level" href="/used-cars/used-cars-dealers">Dealerships </a>
# </li>
# <li>
# <a class="has-submenu js-toggle-finance top-level" href="#">Information <span class="icon-menu-item"></span></a>
# <nav class="menu-links">
# <a class="menu-item--back" href="#"><span class="icon-menu-back"></span> Information</a>
# <ul>
# <li><a href="/used-cars/motoring-advice">Motoring advice</a></li>
# <li><a href="/cars/news/">News</a></li>
# <li><a href="/cars/why-aa-cars">Why AA Cars</a></li>
# </ul>
# </nav>
# </li>
# <li>
# <a class="top-level" href="/cars/account/account">Your account </a>
# </li>
# </ul>
# </nav>
# </div>
# <div class="site-wrap">
# <main>
# <div class="mobile-fixed-buttons">
# <div class="container">
# <div class="row">
# <div class="col-xs-6 finance-message">
# <button class="fb-start-quote btn btn-small btn-full btn-primary aa-finance-btn ga-add-client-id" data-app-source="cardetailsQuoteButton" data-ga-action="car details" data-ga-category="finance" data-ga-label="apply button">
#                                 Get finance quote
#                             </button>
# </div>
# <div class="col-xs-6 chat-call">
# <a class="btn btn-small btn-full btn-call" data-ga-action="car details" data-ga-category="phone" data-ga-label="phone button" href="tel:+442030183769">
# <span class="icon-call"></span> 020 3018 3769
#                         </a>
# </div>
# </div>
# </div>
# </div>
# <div class="container header-links">
# </div>
# <div class="container vehicle-container">
# <div class="top-content clearfix">
# <section class="col-xs-12 col-md-5 col-lg-4 pull-right right-col price-panel">
# <div class="price-finance">
# <div class="price">
# <strong class="total-price">£11,399</strong>
# <span class="previous-price new-transport--light"> was £13,199.</span>
# <p class="monthly-price"><span class="from">From</span>
# <strong>£224</strong>
# <span class="per-month">pm</span></p>
# </div>
# <div class="show-tablet price-finance-btn">
# <button class="fb-start-quote btn btn-full btn-primary aa-finance-btn ga-add-client-id" data-app-source="cardetailsQuoteButton" data-ga-action="car details" data-ga-category="finance" data-ga-label="apply button">
#                                Get a finance quote
#                            </button>
# </div>
# </div>
# </section>
# <section class="col-xs-12 col-md-7 col-lg-8 left-col name-panel">
# <div class="vehicle-name clearfix">
# <div class="col-xs-12 col-md-8">
# <h1><span class="make">Ford</span><span class="model">Fiesta</span> <span class="variant new-transport--regular" title="5Dr Titanium 1.0 100PS">5Dr Titanium 1.0 100PS</span></h1>
# </div>
# <div class="col-xs-12 col-md-4 reviews">
# <div class="review-link" itemscope="" itemtype="http://schema.org/Product">
# <div content="Ford Fiesta 5Dr Titanium 1.0 100PS" itemprop="name"></div>
# <div class="score" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating">
# <div content="373" itemprop="reviewCount"></div>
# <div content="373" itemprop="ratingCount"></div>
# <div content="4.0" itemprop="ratingValue"></div>
# <div class="star-rating">
# <span class="rating-img" style="background-position:0 -168px"></span>
# </div>
# <a href="/used-cars/reviews/ford/fiesta">
#                                         373 Ford Fiesta
#                                                                                     reviews
#                                                                             </a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div class="col-xs-12 col-md-7 col-lg-8 left-col image-panel">
# <section>
# <div class="vd-image video-provider-youtube">
# <div class="vd-image-inner">
# <div class="royalSlider rsUni" id="vd-slider">
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_1.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_2.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_3.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_4.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_5.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_6.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_7.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_8.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_9.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_10.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_11.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_12.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_13.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_14.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_15.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_16.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_17.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_18.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_19.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_20.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_21.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_22.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_23.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_24.jpg">
# </a>
# <a class="rsImg" href="https://image.vcars.co.uk/gforce/2556661_25.jpg">
# </a>
# </div>
# </div>
# </div>
# </section>
# <div class="finance-btn-container">
# <button class="fb-start-quote new-transport--bold aa-finance-btn ga-add-client-id" data-app-source="cardetailsQuoteButton" data-ga-action="car details" data-ga-category="finance" data-ga-label="mobile finance quote button" id="mobile-aa-finance-btn">
#                                 Get a finance quote <span class="icon-arrow-right"></span>
# </button>
# </div>
# <section>
# <div class="links">
# <button class="link" data-table-name="gforce" data-table-uid="2556661" id="add-to-shortlist" type="button">
# <img alt="Heart icon" class="heart-icon" src="https://asset.vcars.co.uk/img/heart-aqua-d9b76a327b.svg"/><span class="text">Save<span class="show-tablet-inline"> to favourites</span></span>
# </button>
# <button class="link enquiry-form-toggle" data-action="/ajax/sendmedetails" data-dealer="Gates of Enfield" data-dealer-id="18952" data-form="emailme_enquiry" data-formsize="400" data-table-name="gforce" data-table-uid="2556661" id="email-me-btn">
# <img alt="mail-icon" class="email-icon" src="https://asset.vcars.co.uk/img/email-icon-aqua-9160609f5e.svg"/>
# <span class="email-me-btn-text">Send me details</span>
# </button>
# <a class="show-desktop-inline-block" href="/used-cars/cardetailsforprint/178344031" id="print-car-details" rel="nofollow" target="_blank" title="Print this page">
# <img alt="printer-icon" class="printer-icon" src="https://asset.vcars.co.uk/img/print-aqua-e5405f0f66.svg"/>
# <span>Print page</span>
# </a>
# </div>
# </section>
# </div>
# <section class="col-xs-12 col-md-5 col-lg-4 right-col pull-right dealer-info">
# <div class="dealer-contact">
# <h2>Contact the dealer</h2>
# <h3>Gates of Enfield</h3>
# <div class="vd-telephone">
# <a class="dealer-phone-num" data-ga-action="car details" data-ga-category="phone" data-ga-label="phone button" href="tel:+442030183769"><span class="phone-icon"></span>
#                                 020 3018 3769<sup>*</sup>
# </a>
# </div>
# <strong class="dealer-open-time">
# <span class="clock-icon"></span>Open now until 6:00 pm
#                             </strong>
# <button class="location link" type="button">
# <span class="location-icon"></span>Get directions                                </button>
# <div class="center-btn">
# <button class="btn btn-primary message-dealer-button" data-dealer="Gates of Enfield" data-did="18952" data-ga-action="car details" data-ga-category="email" data-ga-label="email button" data-tablename="gforce" data-tableuid="2556661" id="js-message-dealer">
#                                     Message dealer
#                                 </button>
# </div>
# <div class="center-btn">
# </div>
# <button class="link" data-ga-action="car details" data-ga-category="external page" data-ga-label="car on dealers website" data-link="http://www.gates.co.uk/used-cars/reg/EJ19LPU?utm_source=173&amp;utm_medium=3&amp;utm_campaign=CM000077-1" id="dealer-website-button">View on dealers website
#                             </button>
# <div class="center-btn">
# <a href="/used-cars/dealers/gates-of-enfield">
#                                     View all stock at this dealer
#                                 </a>
# </div>
# </div>
# <div class="call-small-print">
# <small>* Calls may be recorded for training and monitoring purposes. Please refrain from providing credit/debit card information on these calls. If you do so it is at your own risk.</small>
# </div>
# </section>
# <section class="col-xs-12 col-md-7 col-lg-8 left-col specs-panel">
# <div class="white-panel overview">
# <h3>Overview</h3>
# <ul class="vd-specs-list clearfix">
# <li class="vd-spec">
# <span class="vd-spec-icon vd-spec-icon--mileage"></span>
# <span class="vd-spec-label">Mileage:<br/>
# <span class="vd-spec-value">12,937</span>
# </span>
# </li>
# <li class="vd-spec">
# <span class="vd-spec-icon vd-spec-icon--year"></span>
# <span class="vd-spec-label">Year:<br/>
# <span class="vd-spec-value">2019</span>
# </span>
# </li>
# <li class="vd-spec">
# <span class="vd-spec-icon vd-spec-icon--fueltype"></span>
# <span class="vd-spec-label">Fuel type:
#                                     <span class="vd-spec-value">Petrol</span>
# </span>
# </li>
# <li class="vd-spec">
# <span class="vd-spec-icon vd-spec-icon--transmission"></span>
# <span class="vd-spec-label">Transmission:
#                                     <span class="vd-spec-value">Manual</span>
# </span>
# </li><li class="vd-spec">
# <span class="vd-spec-icon vd-spec-icon--bodytype"></span>
# <span class="vd-spec-label">Body type:
#                                     <span class="vd-spec-value" title="Hatchback">Hatchback</span>
# </span>
# </li>
# <li class="vd-spec">
# <span class="vd-spec-icon vd-spec-icon--colour"></span>
# <span class="vd-spec-label">Colour:
#                                     <span class="vd-spec-value" title="Shadow black (premium colour)">Shadow black (premium colour)</span>
# </span>
# </li>
# <li class="vd-spec">
# <span class="vd-spec-icon vd-spec-icon--doors"></span>
# <span class="vd-spec-label">Doors:
#                                     <span class="vd-spec-value">5</span>
# </span>
# </li>
# <li class="vd-spec">
# <span class="vd-spec-icon vd-spec-icon--enginesize"></span>
# <span class="vd-spec-label">Engine size:
#                                     <span class="vd-spec-value">1.0 L</span>
# </span>
# </li>
# <li class="vd-spec">
# <span class="vd-spec-icon vd-spec-icon--co2"></span>
# <span class="vd-spec-label">CO<sub>2</sub> Emissions:
#                                     <span class="vd-spec-value">110 g/km</span>
# </span>
# </li>
# </ul>
# <ul class="tco clearfix">
# <li class="tco-mpg">
# <span class="tco-label">Mpg:</span><span class="icon-info tco-info"></span>
# <span class="tco-value">49.6 miles</span>
# <p class="tco-tooltip">This is the average amount of miles it takes the car to use a gallon of fuel. The figure is used to see how efficient
#                                     the car is with its fuel. For a typical petrol-powered family hatchback, anything above 40mpg is considered respectable. The higher the
#                                     figure here, the more efficient the car is.</p>
# </li>
# <li class="tco-mpg">
# <span class="tco-label">Mpg urban:</span><span class="icon-info tco-info"></span>
# <span class="tco-value">48.7 miles</span>
# <p class="tco-tooltip">This number is calculated when the car is driven on a test cycle through towns and cities. As vehicles are more likely
#                                     to be continually stopping and starting, they'll use more fuel getting the car back up to speed – lowering its fuel efficiency compared
#                                     to the average.</p>
# </li>
# <li class="tco-mpg">
# <span class="tco-label">Mpg extra urban:</span><span class="icon-info tco-info"></span>
# <span class="tco-value">68.9 miles</span>
# <p class="tco-tooltip">When driven on roads in and out of town, the car will be able to cruise at points – using less fuel. This figure takes
#                                     that into account, as when a car is sitting at a constant speed, it typically uses less fuel than one that's in stop-start traffic.</p>
# </li>
# <li>
# <span class="tco-label">Insurance group:</span><span class="icon-info tco-info"></span>
# <span class="tco-value">10</span>
# <p class="tco-tooltip">Every car is given an insurance group between 1 (the lowest) and 50 (the highest). Cars that are less powerful and more common
#                                     come with a lower insurance grouping - whereas supercars, sports car and rarer models come with a higher grouping.</p>
# </li>
# </ul>
# </div>
# </section>
# </div>
# <div class="lower-left-content col-xs-12 col-md-7 col-lg-8 left-col">
# <article class="vehicle-details white-panel">
# <div class="description">
# <h3>Vehicle details</h3>
# <p class="description-text">Ford Fiesta 1.0 EcoBoost Titanium 5dr</p>
# <button id="read-more-btn" name="button" type="button">Read more...</button>
# </div>
# <h3 class="features-heading">Vehicle features</h3>
# <ul class="features clearfix">
# <li title="Alloy Wheel Upgrade">Alloy Wheel Upgrade</li>
# <li title=" Privacy Glass"> Privacy Glass</li>
# <li title=" Satellite Navigation"> Satellite Navigation</li>
# </ul>
# <button class="link show-features" name="button">Show all</button>
# <small>Remember to check the details of this car with the dealer before you buy it to make sure that all the information is accurate.</small>
# </article>
# <article class="credit-info-overlay">
# <h4>Credit ratings explained</h4>
# <span class="close-form icon-cross"></span>
# <div class="overlay-content">
# <article>
# <h5>Excellent</h5>
# <ul>
# <li>You are a home owner</li>
# <li>You have been on the electoral roll for a long period of time</li>
# <li>You have current credit arrangements and mortgage with no defaults</li>
# <li>You have no CCJs, credit arrears or missed payments</li>
# <li>You rarely apply for credit</li>
# <li>You are employed or self-employed</li>
# </ul>
# </article>
# <article>
# <h5>Good</h5>
# <ul>
# <li>You are on the electoral roll</li>
# <li>You are a home owner or long standing-tenant</li>
# <li>You have a stable employment history</li>
# <li>You have current credit arrangements with occasional missed payments</li>
# <li>You have no CCJs</li>
# </ul>
# </article>
# <article>
# <h5>Fair</h5>
# <ul>
# <li>You are or have recently been on the electoral roll</li>
# <li>You may have recently changed address</li>
# <li>You may have occasional missed payments</li>
# <li>You may have an old CCJ</li>
# <li>You may have regularly applied for credit</li>
# </ul>
# </article>
# <article>
# <h5>Poor</h5>
# <ul>
# <li>You may have had frequent changes in address</li>
# <li>You may not be traceable on the voters roll</li>
# <li>You may have exceeded credit card limits</li>
# <li>You may have missed payments on current agreements</li>
# <li>You may have had a CCJ in the past</li>
# </ul>
# </article>
# <article>
# <h5>Bad</h5>
# <ul>
# <li>You may not be traceable on the voters roll</li>
# <li>Your credit cards are over their limits</li>
# <li>You have recent CCJs</li>
# <li>You may have been refused credit elsewhere</li>
# <li>You may be in a debt management plan</li>
# </ul>
# </article>
# </div>
# </article>
# <section class="calculator-wrapper">
# <div id="finance-calculator">
# <div class="calculator-intro">
# <h3>Finance calculator</h3>
# <p class="line-seperator">Calculate how affordable this <strong class="strong-inline">Ford Fiesta</strong> could be per month.</p>
# </div>
# <form class="vehicle-calculator clearfix">
# <div class="form-field">
# <label for="credit-rating">My credit score is<span class="icon-info" id="credit-score-info"></span></label>
# <div class="styled-select">
# <select id="credit-rating" name="credit-rating">
# <option selected="" value="6.9">Excellent</option>
# <option value="9.9">Good</option>
# <option value="16.9">Fair</option>
# <option value="19.9">Poor</option>
# <option value="29.9">Bad</option>
# </select>
# </div>
# </div>
# <div class="form-field">
# <label for="cash-price">Cash price </label>
# <div class="pound-input">
# <span class="input-pound-symbol">£</span>
# <input class="input-pound" id="cash-price" name="cash-price" readonly="" type="text" value="11,399.00"/>
# </div>
# </div>
# <div class="form-field">
# <label for="deposit">Deposit</label>
# <div class="pound-input">
# <span class="input-pound-symbol">£</span>
# <input class="input-pound" id="deposit" maxlength="8" name="deposit" title="Only digits(0-9) allowed" type="text" value="0"/>
# </div>
# </div>
# <div class="form-field">
# <label for="hp-term">I would like to pay over</label>
# <div class="styled-select">
# <select id="hp-term" name="hp-term">
# <option value="24">24 Months</option>
# <option value="36">36 Months</option>
# <option value="48">48 Months</option>
# <option selected="" value="60">60 Months</option>
# </select>
# </div>
# </div>
# </form>
# </div>
# <section class="results-section">
# <h4>Hire purchase (HP)</h4>
# <div class="calculation-result">
# <ul>
# <li><label>Amount to borrow</label><output id="amount-to-borrow" name="amount-to-borrow"></output></li>
# <li><label>Monthly payments</label><output id="monthly-payment" name="monthly-payment"></output></li>
# <li><label>Illustrative APR</label><output id="apr" name="apr"></output></li>
# <li><label>Total amount payable</label><output id="total-payment" name="total-payment"></output></li>
# </ul>
# </div>
# <div class="apply-btn-area">
# <button class="fb-start-quote btn btn-primary aa-finance-btn ga-add-client-id" data-app-source="cardetailsCalculator" data-ga-action="car details calculator" data-ga-category="finance" data-ga-label="apply button">
#                                Apply now
#                            </button>
# </div>
# </section>
# <output aria-hidden="true" class="hidden" hidden="" id="hidden-apr"></output>
# <output aria-hidden="true" class="hidden" hidden="" id="hidden-regpay"></output>
# <output aria-hidden="true" class="hidden" hidden="" id="hidden-final"></output>
# <div class="rep-example">
# <strong>Representative example: Annual Interest Rate (fixed) <span id="annual-apr"></span>% p.a., with a representative <span id="representative-apr"></span>% APR, total amount of credit
#                             £<span id="rep-amount"></span>, deposit of £<span id="rep-deposit"></span>, repaying over <span id="rep-term"></span> monthly payments of
#                             £<span id="rep-monthly"></span> followed by 1 payment of £<span id="rep-final"></span>, total cost of credit is £<span id="rep-credit"></span>*,
#                             total amount payable is £<span id="rep-total"></span>.</strong>
# <p>*The representative example includes an estimated option to purchase fee of £10. This is subject to status and although fees may vary in amount
#                             and when payable, the total cost of credit and APR received will not alter.</p>
# </div>
# <div class="rep-ex-smallprint">
# <small>This representative example is for illustration purposes only and does not constitute an offer. Written quotations are available on request
#                             and finance is subject to status. Terms and conditions apply. A guarantee may be required. Over 18's only. This service is provided by Evolution
#                             Funding Limited who are authorised and regulated by the Financial Conduct Authority for credit brokerage, FCA number is 823324. Evolution Funding
#                             Limited are a credit broker, not a lender. Other offers may be available but cannot be used in conjunction with this offer. We work with a number
#                             of carefully selected credit providers who may be able to offer you finance for your purchase. We are only able to offer finance products from
#                             these providers and they may provide an incentive to do so.</small>
# </div>
# <div class="understand-finance">
# <h3>Need car finance demystifying?</h3>
# <p>Let us break it down for you. Finance can be confusing, but we’ve made it simple.</p>
# <a class="btn btn-secondary" href="/cars/finance">Understanding finance</a>
# </div>
# </section>
# <article class="history-check white-panel">
# <h3>Vehicle history check</h3>
# <p class="line-seperator">For <strong class="vrm strong-inline">EJ19LPU</strong></p>
# <ul class="tick-list">
# <li>
# <span class="icon-tick"></span>Not recorded as stolen
#                                                     </li>
# <li>
# <span class="icon-tick"></span>No third-party trace
#                                                     </li>
# <li>
# <span class="icon-tick"></span>Not an insurance write-off
#                                                     </li>
# <li class="has-tooltip">
# <span class="icon-tick"></span>0 previous keepers
#                                                         <a class="ac-tooltip-btn" href="#tooltip-previousKeepers">show</a>
# <div class="ac-tooltip" style="display: none;">
# <p>The current keeper is not included in the number of previous keepers.</p>
# <p class="no-margin">This vehicle has had <strong class="strong-inline">1</strong> registered keeper from new.
#                                     Please note that the keeper is not necessarily the owner, it may be a company vehicle or belong to a third party.</p>
# </div>
# </li>
# <li>
# <span class="icon-tick"></span>No plate changes
#                                                     </li>
# <li>
# <span class="icon-tick"></span>No colour changes
#                                                     </li>
# <li>
# <span class="icon-tick"></span>Mileage data available †
#                                                         <a class="ac-tooltip-btn" href="#tooltip-mileage">show</a>
# <div class="ac-tooltip" style="display: none;">
# <p></p>
# <table>
# <tbody>
# <tr>
# <td>Source</td>
# <td>Date</td>
# <td>Mileage</td>
# </tr>
# <tr>
# <td>DVLA</td>
# <td>19/10/2020</td>
# <td>13,000</td>
# </tr>
# </tbody>
# </table>
# </div>
# </li>
# </ul>
# <small>
#                         Data for this history check supplied:
#                         <strong class="strong-inline">23/01/2021</strong>
#                         at
#                         <strong class="strong-inline">06:18</strong>
# </small>
# </article>
# <section>
# <div class="buy-with-aa white-panel clearfix">
# <h3>Buy with the AA</h3>
# <p class="line-seperator">
#                                                             This dealer is an AA approved franchise dealer.
#                                                     </p>
# <div class="breakdown-cover-badge">
# <img alt="AA Breakdown Cover badge" height="30" loading="lazy" src="https://asset.vcars.co.uk/img/aa-logo-block-bb3843314a.svg" width="30"/>
# <h4>Free Breakdown Cover</h4>
# <p>12 months’ free breakdown cover, or an upgrade if you’re a member</p>
# <a href="/used-cars/free-cover">Find out more</a>
# </div>
# </div>
# </section>
# </div>
# <div class="lower-right-content col-xs-12 col-md-5 col-lg-4 right-col pull-right">
# <section class="breakdown-prompt">
# <h3>Free AA breakdown cover</h3>
# <ul class="tick-list">
# <li><span class="icon-tick"></span>12 months of Basic Breakdown Cover</li>
# <li><span class="icon-tick"></span>Free upgrade for existing members^</li>
# </ul>
# <p>For extra peace of mind, every vehicle qualifies for breakdown cover.</p>
# <a class="btn btn-primary btn-full" data-ga-action="car details" data-ga-category="breakdown cover" data-ga-label="find out button" href="/used-cars/free-cover">Find out more</a>
# <div>
# <small>^T&amp;C’s apply</small>
# </div>
# </section>
# <section class="valuation-prompt">
# <h3>Selling? Get a valuation</h3>
# <ul class="tick-list">
# <li><span class="icon-tick"></span>Quick &amp; easy</li>
# <li><span class="icon-tick"></span>100s of dealers</li>
# </ul>
# <p>Get a valuation quickly and choose offers from hundreds of approved dealers.</p>
# <a class="btn btn-secondary" href="/used-cars/valuation">Get a valuation now</a>
# </section>
# <section class="alternative-cars">
# <h2>Other recommendations</h2>
# <div class="vehicle-card">
# <div class="img-link">
# <a href="/used-cars/cardetails/14-2575852" rel="nofollow">
# <img alt="Ford Fiesta 5Dr Titanium 1.0 100PS" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2575852_1.jpg"/>
# </a>
# </div>
# <h3 class="new-transport--regular" title="Ford Fiesta 5Dr Titanium 1.0 100PS">
# <span class="make-model new-transport--bold">Ford Fiesta</span>
# <span class="variant">5Dr Titanium 1.0 100PS</span>
# </h3>
# <div class="view-and-price clearfix">
# <a class="btn btn-primary view" href="/used-cars/cardetails/14-2575852" rel="nofollow">
#             View
#         </a>
# <div class="rel-price-info" title="£11,899 + VAT  was £12,399">
# <strong class="rel-price new-transport--bold">£11,899</strong>
# <span class="rel-previous-price new-transport--light"> was £12,399</span>
# </div>
# </div>
# </div>
# <div class="vehicle-card">
# <div class="img-link">
# <a href="/used-cars/cardetails/14-2591883" rel="nofollow">
# <img alt="Ford Fiesta 5Dr Titanium 1.0 125PS" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2591883_1.jpg"/>
# </a>
# </div>
# <h3 class="new-transport--regular" title="Ford Fiesta 5Dr Titanium 1.0 125PS">
# <span class="make-model new-transport--bold">Ford Fiesta</span>
# <span class="variant">5Dr Titanium 1.0 125PS</span>
# </h3>
# <div class="view-and-price clearfix">
# <a class="btn btn-primary view" href="/used-cars/cardetails/14-2591883" rel="nofollow">
#             View
#         </a>
# <div class="rel-price-info" title="£10,599 + VAT  was £10,899">
# <strong class="rel-price new-transport--bold">£10,599</strong>
# <span class="rel-previous-price new-transport--light"> was £10,899</span>
# </div>
# </div>
# </div>
# <div class="vehicle-card">
# <div class="img-link">
# <a href="/used-cars/cardetails/14-2598729" rel="nofollow">
# <img alt="Ford Fiesta 5Dr Zetec 1.1 85PS" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2598729_1.jpg"/>
# </a>
# </div>
# <h3 class="new-transport--regular" title="Ford Fiesta 5Dr Zetec 1.1 85PS">
# <span class="make-model new-transport--bold">Ford Fiesta</span>
# <span class="variant">5Dr Zetec 1.1 85PS</span>
# </h3>
# <div class="view-and-price clearfix">
# <a class="btn btn-primary view" href="/used-cars/cardetails/14-2598729" rel="nofollow">
#             View
#         </a>
# <div class="rel-price-info">
# <strong class="rel-price new-transport--bold">£10,000</strong>
# </div>
# </div>
# </div>
# <div class="vehicle-card">
# <div class="img-link">
# <a href="/used-cars/cardetails/14-2598035" rel="nofollow">
# <img alt="Ford Fiesta 3Dr Zetec 1.1 85PS" loading="lazy" src="https://thumb.vcars.co.uk/gforce/2598035_1.jpg"/>
# </a>
# </div>
# <h3 class="new-transport--regular" title="Ford Fiesta 3Dr Zetec 1.1 85PS">
# <span class="make-model new-transport--bold">Ford Fiesta</span>
# <span class="variant">3Dr Zetec 1.1 85PS</span>
# </h3>
# <div class="view-and-price clearfix">
# <a class="btn btn-primary view" href="/used-cars/cardetails/14-2598035" rel="nofollow">
#             View
#         </a>
# <div class="rel-price-info">
# <strong class="rel-price new-transport--bold">£9,299</strong>
# </div>
# </div>
# </div>
# </section>
# </div>
# </div>
# <div class="dealer-directions"></div>
# <div class="form-panel enquiry-form" id="dealer-enquiry-form-dialog">
# </div>
# <div class="form-panel" id="send-me-details-form-dialog">
# </div>
# <div class="form-panel" id="callback-request-form-dialog">
# </div>
# <div id="finance-application"></div>
# </main>
# <aside>
# <section class="terms-and-disclosure">
# <div class="container">
# <div class="collapse">
# <div class="collapse-trigger">
# <h3 tabindex="0">Terms and conditions</h3>
# </div>
# <div class="collapse-content">
# <div class="collapse-inner">
# <article>
# <h4>Non Member and existing Member AA Breakdown Cover offer terms</h4>
# <p>The free Basic Breakdown Cover and the existing Member offer are only available when a vehicle is purchased through AA Cars and must be redeemed within
#                               6 months of purchase. The Basic Breakdown Cover offer is for non-members only. This offer is only available for the first 12 months of cover. Existing
#                               Members who take up the free upgrade will be renewed automatically for the selected upgrade unless we are told otherwise. The upgrade is for the remainder
#                               of the membership year thereafter the renewal price will be the standard price (at the time of renewal) for the chosen level of cover.This offer is not
#                               available in a breakdown situation and can be withdrawn or varied at any time. Breakdown Cover is subject to terms and conditions. AA Breakdown Cover is
#                               arranged by Automobile Association Insurance Services Limited. Registered address: Fanum House, Basing View, Basingstoke, Hampshire RG21 4EA. Registered
#                               in England and Wales number 2414212. Automobile Association Insurance Services Limited is authorised and regulated by the Financial Conduct Authority.</p>
# </article>
# <div class="row privacy-links">
# <div class="col-xs-12 col-md-4 privacy-link">
# <a href="https://www.evolutionfunding.com/privacy-policy/" rel="nofollow" target="_blank">Evolution Privacy Policy</a>
# </div>
# <div class="col-xs-12 col-md-4 privacy-link">
# <a href="/cars/privacy-notice" rel="nofollow">AA Cars Privacy Notice</a>
# </div>
# <div class="col-xs-12 col-md-4 privacy-link">
# <a href="https://www.theaa.com/cars/customer_terms_and_conditions.pdf" rel="nofollow" target="_blank">Customer terms &amp; conditions</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="mileage-disclaimer">
# <small>
#                         † All information in this site relating to the history check of a vehicle is provided by Experian Ltd.
#                         AA Cars provides no guarantee of completeness, accuracy or timeliness of this information and it provides no warranty or representation whatsoever in
#                         relation to such information. In no event will AA Cars, its related partnerships or corporations, or the partners, agents or employees thereof be liable
#                         to you or anyone else for any decision made or action taken in reliance on this information or for any consequential, special or similar damages, even if
#                         advised of the possibility of such damages.
#                     </small>
# </div>
# <small>AA Car Finance and AA Cars are trading names of Used Car Sites Limited. Registered address: Fanum House, Basing View, Basingstoke, Hampshire, RG21 4EA.
#                 Used Car Sites Limited is authorised and regulated by the Financial Conduct Authority (firm reference number 671360). AA Cars introduces AA Car Finance
#                 customers to Evolution Funding Limited. Evolution Funding Limited is authorised and regulated by the Financial Conduct Authority (firm reference number
#                 823324). Registered address: Thompson Close, Whittington Moor, Chesterfield, Derbyshire, S41 9AZ. Evolution Funding Limited and Used Car Sites Limited are
#                 credit brokers not lenders.</small>
# <small>Evolution Funding Limited is only able to offer a range of finance products from a group of carefully selected credit providers, which may be suitable
#                 for you and they will explain the key features of these products to you. AA Cars receives payment from Evolution Funding for introducing you to them. The
#                 amount AA Cars receives does not impact the amount that you pay the lender or the interest rate you are offered. The payment received is based on a fixed
#                 fee or a percentage of the amount you borrow, varying by lender, the amount you borrow and the term the loan is borrowed over. AA Cars will not charge you
#                 any fee for our services.</small>
# <small>Finance subject to status. Terms and Conditions apply. A guarantee may be required. Over 18’s only. PLEASE ENSURE YOU CAN AFFORD THE REPAYMENTS FOR THE
#                 DURATION OF A LOAN BEFORE ENTERING INTO A CREDIT AGREEMENT.</small>
# </div>
# </section>
# </aside>
# <div class="form-panel" id="user-login-form-dialog">
# </div>
# <div class="social-links">
# <h3>Connect with us</h3>
# <a href="https://www.facebook.com/TheAACars" rel="nofollow" target="_blank">
# <img alt="Facebook" height="50" loading="lazy" src="https://asset.vcars.co.uk/img/fb-social-icon-57980334f0.png"/>
# </a>
# <a href="https://twitter.com/TheAACars" rel="nofollow" target="_blank">
# <img alt="Twitter" height="50" loading="lazy" src="https://asset.vcars.co.uk/img/tw-social-icon-6f391e824e.png"/>
# </a>
# <a href="https://www.youtube.com/user/theAAPatrol" rel="nofollow" target="_blank">
# <img alt="YouTube" height="50" loading="lazy" src="https://asset.vcars.co.uk/img/yt-social-icon-044ee3e6c6.png"/>
# </a>
# <a href="https://www.linkedin.com/company/aa-cars/" rel="nofollow" target="_blank">
# <img alt="LinkedIn" height="50" loading="lazy" src="https://asset.vcars.co.uk/img/in-social-icon-1dd0cb03bf.png"/>
# </a>
# </div>
# <footer id="site-footer">
# <div class="container">
# <div class="row">
# <div class="col-xs-12 col-md-3">
# <h5>For customers</h5>
# <ul class="footer-links">
# <li><a href="/cars/customer_terms_and_conditions.pdf" rel="nofollow" target="_blank">Customer
#                                             terms &amp; conditions</a></li>
# <li><a href="/cars/approved-dealers-consumer">Our approved dealers (consumer)</a></li>
# <li><a href="/cars/site/aa-cars-qa" rel="nofollow">AA Cars Q &amp; A</a></li>
# <li><a href="/cars/privacy-notice" rel="nofollow">Privacy notice</a></li>
# <li><a href="https://www.theaa.com/cookie-policy" rel="nofollow" target="_blank">Cookie policy</a></li>
# <li><a href="/cars/customer_dsar_request_form.pdf">Customer data request form</a></li>
# </ul>
# </div>
# <div class="col-xs-12 col-md-3">
# <h5>For dealers</h5>
# <ul class="footer-links">
# <li><a href="/cars/dealer_terms_and_conditions.pdf" rel="nofollow" target="_blank">Car dealer
#                                             terms &amp; conditions</a></li>
# <li><a href="/cars/approved-dealers-trade">Our approved dealers (trade)</a></li>
# <li><a href="/cars/advertise-with-us">Advertise with us</a></li>
# </ul>
# </div>
# <div class="col-xs-12 col-md-2">
# <h5>Others</h5>
# <ul class="footer-links footer-links--other">
# <li><a href="/cars/about-us">About us</a></li>
# <li><a href="/cars/site/sitemap">Sitemap</a></li>
# <li><a href="/cars/site/contact-us">Contact us</a></li>
# </ul>
# </div>
# <div class="col-xs-12 col-md-4">
# <h5>Vehicle Inspections</h5>
# <div class="aa-recommends">
# <p>The AA recommends an AA Cars Vehicle Inspection before purchase. Not all cars are
#                                         mechanically checked by the AA</p>
# <p><a class="footer-aa-link" href="https://www.theaa.com" rel="nofollow" target="_blank">theAA.com</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-copyright">
#                     © AA Cars 2021  | <span class="company-number">Company No. 4546950  |  VAT No. 806075443</span>
#                 </div>
# </footer>
# </div> <!-- end site-wrap -->
# </div><!-- end outer-wrap - used for restricting width on 4k screens -->
# <script>
#         window.vehicle = {
#             feedUid: '14',
#             tableName: 'gforce',
#             vehicleUid: '2556661'
#         };
#         window.directionData = {
#             fullpostcode: '',
#             did: '18952',
#             dealer: 'Gates of Enfield'
#         };
#     </script>
# <script>
#         var deep_link_tracking_data = {
#             price: 11399,
#             make: 'Ford',
#             model: 'Fiesta',
#             makeid: 113,
#             modelid: 109,
#             vehicle: 'Ford Fiesta 5Dr Titanium 1.0 100PS'
#         };
#         </script>
# <script>
#
# window.VC = {
#     environment: {
#         uri: '/used-cars/cardetails/14-2556661',
#         route_name: 'display_vehicle'
#     },
#     tracking: {
#     "pageView_ipAddress": "92.234.28.210",
#     "pageView_postcode": "",
#     "pageView_makeId": 0,
#     "pageView_modelId": 0,
#     "pageView_dealerId": 0,
#     "pageView_carsFound": 0,
#     "pageView_carsDisplayed": 0,
#     "pageView_page": "\/used-cars\/cardetails\/14-2556661",
#     "pageView_query": "",
#     "pageView_internalReferrer": "",
#     "pageView_mobile": null,
#     "pageView_date": "2021-02-05 14:55:28",
#     "vehicleView_dealerId": "18952",
#     "vehicleView_tableName": "gforce",
#     "vehicleView_tableUid": 2556661,
#     "vehicleView_make": "Ford",
#     "vehicleView_model": "Fiesta",
#     "vehicleView_variant": "5Dr Titanium 1.0 100PS",
#     "vehicleView_makeId": 113,
#     "vehicleView_modelId": 109
# },
#     pcp: false,
#     pcpTerm: 36,
#     pcpDefaultDepositPercent: 10,
# };
#
#     if (VC.environment.route_name === 'display_vehicle') {
#         VC.image = "https://thumb.vcars.co.uk/gforce/2556661_1.jpg";
#     }
#
# </script>
# <script src="https://asset.vcars.co.uk/js/script-afb08ed555.js"></script>
# <script src="https://asset.vcars.co.uk/js/plugins/jquery-94a25d4c1a.royalslider.min.js"></script>
# <script src="https://asset.vcars.co.uk/js/car-details-init-image-slider-87c7097cfc.js"></script>
# <script>
#         var tablename = 'gforce';
#         var tableuid = '2556661';
#         var carPrice = '11399';
#         var makeModel = 'Ford Fiesta';
#         var vehicleType = 'Car';
#         var dealer_postcode = 'EN13WX';
#
#                     //Will record each time a car details page is viewed
#             fbq('track', 'ViewContent', {
#                 content_type: 'product',
#                 content_ids: [tablename + tableuid],
#                 content_name: makeModel,
#                 content_category: vehicleType
#             });
#             </script>
# <script>
#         // This is for special cases where there is just a youtube video and no images for the vehicle
#         // When there are both it is handled by Royal Slider
#                                 </script>
# <script>
#             window.appSource = '';
#
#             (function($) {
#                 $('.aa-finance-btn').on('click', function(event) {
#                     window.appSource = $(event.target).data('app-source');
#
#                     $.getScript('https\u003A\/\/asset.vcars.co.uk\/js\/index\u002D00b7494910.js');
#                 });
#             })(jQuery);
#         </script>
# <script>
#                 var VC_SETTINGS = {
#                     "id": "18952",
#                     "name": "Gates of Enfield",
#                     "accountId": 39,
#                     "data": {
#                         "advert": "Ford Fiesta 5Dr Titanium 1.0 100PS",
#                         "advertId": "2556661",
#                         "dealerid": "18952",
#                         "tablename": "gforce",
#                         "tableuid": "2556661",
#                         "price": "11399",
#                         "make": "Ford",
#                         "model": "Fiesta",
#                         "makeid": "113",
#                         "modelid": "109",
#                         "variant": "5Dr Titanium 1.0 100PS",
#                         "postcode": "",
#                         "ipaddress": "92.234.28.210"
#                     }
#                 }
#             </script>
# </body>
# </html>

# %% [markdown]
# Let's try to extract necessary information from this page

# %%
name = soup.find('div', class_ = 'col-xs-12 col-md-8').h1.text
print(name)
# Out:
# FordFiesta 5Dr Titanium 1.0 100PS

# %%
price = soup.find('div', class_ = 'price').strong.text
print(price)
# Out:
# £11,399

# %% [markdown]
# Now, certain data on this page is scripted as list items, so we'll make a for loop to extract information from this list

# %%
result = []
for li in soup.find('ul', class_ = 'vd-specs-list clearfix').find_all('li'):
    result.append(list(li.stripped_strings))

print(result)
# Out:
# [['Mileage:', '12,937'], ['Year:', '2019'], ['Fuel type:', 'Petrol'], ['Transmission:', 'Manual'], ['Body type:', 'Hatchback'], ['Colour:', 'Shadow black (premium colour)'], ['Doors:', '5'], ['Engine size:', '1.0 L'], ['CO', '2', 'Emissions:', '110 g/km']]

# %% [markdown]
# Since, we've extracted the list items as a list, we'll extract information from this list using pop command

# %%
mileage = result[0].pop()
print(mileage)
# Out:
# 12,937

# %%
year = result[1].pop()
print(year)
# Out:
# 2019

# %%
fuel = result[2].pop()
print(fuel)
# Out:
# Petrol

# %%
engine_size = result[7].pop()
print(engine_size)
# Out:
# 1.0 L

# %%
emission = result[8].pop()
print(emission)
# Out:
# 110 g/km

# %% [markdown]
# There's another list found on this page, so I created a new for loop to extract information from it

# %%
ig_results = []
for li in soup.find('ul',class_ = 'tco clearfix').find_all('li'):
    ig_results.append(list(li.stripped_strings))
    
print(ig_results)
# Out:
# [['Mpg:', '49.6 miles', 'This is the average amount of miles it takes the car to use a gallon of fuel. The figure is used to see how efficient\n                                    the car is with its fuel. For a typical petrol-powered family hatchback, anything above 40mpg is considered respectable. The higher the\n                                    figure here, the more efficient the car is.'], ['Mpg urban:', '48.7 miles', "This number is calculated when the car is driven on a test cycle through towns and cities. As vehicles are more likely\n                                    to be continually stopping and starting, they'll use more fuel getting the car back up to speed – lowering its fuel efficiency compared\n                                    to the average."], ['Mpg extra urban:', '68.9 miles', "When driven on roads in and out of town, the car will be able to cruise at points – using less fuel. This figure takes\n                                    that into account, as when a car is sitting at a constant speed, it typically uses less fuel than one that's in stop-start traffic."], ['Insurance group:', '10', 'Every car is given an insurance group between 1 (the lowest) and 50 (the highest). Cars that are less powerful and more common\n                                    come with a lower insurance grouping - whereas supercars, sports car and rarer models come with a higher grouping.']]

# %%
in_group = ig_results[3].pop(-2)
print(in_group)
# Out:
# 10

# %% [markdown]
# Now that I have extracted all the information I require for a single car, I shall create a dictionary for this car.

# %%
car = {
    'name': name,
    'price': price,
    'mileage': mileage,
    'year': year,
    'fuel': fuel,
    'engine_size': engine_size,
    'emission': emission,
    'insurance group': in_group
}
print(car)
# Out:
# {'name': 'FordFiesta 5Dr Titanium 1.0 100PS', 'price': '£11,399', 'mileage': '12,937', 'year': '2019', 'fuel': 'Petrol', 'engine_size': '1.0 L', 'emission': '110 g/km', 'insurance group': '10'}

# %% [markdown]
# <a id='task6'></a>
# # Task 6: Extracting information of all the products

# %% [markdown]
# Now, I want to extract information for all the cars. So, I shall use a for loop again to get this informtaion.

# %%
carlist = []
for link in productlinks:
    r = requests.get(link, headers = header)
    soup = BeautifulSoup(r.content, 'lxml')
    try:
        name = soup.find('div', class_ = 'col-xs-12 col-md-8').h1.text
    except: 
        name = 'not given'
    try: 
        price = soup.find('div', class_ = 'price').strong.text
    except: 
        price = 'not given'
    result = []
    links = soup.find('ul', class_ = 'vd-specs-list clearfix').find_all('li')
    for li in links:
        result.append(list(li.stripped_strings))
        
    try: 
        mileage = result[0].pop()
    except: 
        mileage = 'not given'
    try: 
        year = result[1].pop()
    except: 
        year = 'not given'
    try: 
        engine_size = result[7].pop()
    except: 
        engine_size = 'not given'
    try: 
        emission = result[8].pop()
    except: 
        emission = 'not given'
        
     
    car = {
    'name': name,
    'price': price,
    'mileage': mileage,
    'year': year,
    'fuel': fuel,
    'engine_size': engine_size,
    'emission': emission
    }
    
    carlist.append(car)
    print('Saving:', car['name'])

df = pd.DataFrame(carlist)
print(df.head)
# Out:
# Saving: MINIClubman COOPER CLASSIC
# Saving: MINICooper Convertible COOPER CLASSIC
# Saving: AudiA1 SPORTBACK TFSI SPORT
# Saving: BMW1 Series 1.6 116i M Sport Sports Hatch (s/s) 5dr
# Saving: BMW1 Series 2.0 116i Sport 3dr
# Saving: not given
# Saving: BMW1 SERIES 120i SPORT
# Saving: FordFiesta 5Dr ST-Line X Edition 1.0 125PS Auto
# Saving: FordFiesta 5Dr Titanium 1.0 Hybrid 125PS
# Saving: FordFiesta 5Dr ST-2 1.5 200PS
# Saving: FordFiesta 5Dr Titanium 1.0 Hybrid 125PS
# Saving: FordFiesta 5Dr ST-Line Edition 1.0 Hybrid 125PS
# Saving: FordFiesta Vignale Fiesta 5Dr Vignale 1.0 140PS
# Saving: FordFiesta Vignale Fiesta 5Dr Vignale Edition 1.0 125PS
# Saving: FordFiesta 5Dr Active X 1.0 100PS
# Saving: FordFiesta 5Dr ST-Line X 1.0 125PS
# Saving: FordFiesta 5Dr ST-Line 1.0 125PS
# Saving: FordFiesta 5Dr ST-Line X 1.0 125PS
# Saving: FordFiesta 5Dr Active X 1.0 125PS
# Saving: FordFiesta 5Dr Titanium 1.0 100PS
# Saving: FordFiesta 5Dr Titanium 1.0 100PS
# Saving: FordFiesta 3Dr ST-Line 1.0 140PS
# Saving: FordFiesta 5Dr Zetec 1.0 100PS Auto
# Saving: FordFiesta 5Dr Zetec 1.0 100PS Auto
# Saving: FordFiesta 5Dr Titanium 1.0 125PS
# Saving: FordFiesta 3Dr Zetec 1.0 100PS Auto
# Saving: FordFiesta 5Dr Zetec 1.1 85PS
# Saving: FordFiesta 3Dr Zetec 1.1 85PS
# Saving: FordFiesta 5Dr Zetec 1.0 100PS
# Saving: FordFiesta 5Dr Zetec 1.1 85PS
# Saving: FordFiesta 3Dr Zetec 1.1 85PS
# Saving: FordFiesta 5Dr Zetec 1.0 100PS
# Saving: FordKa+ 5Dr Zetec 1.2 85PS
# Saving: RenaultClio 1.6 E-TECH Hybrid 140 S Edition 5dr Auto
# Saving: RenaultClio 1.3 TCe 130 RS Line 5dr EDC
# Saving: RenaultClio 1.3 TCe 130 RS Line 5dr EDC
# Saving: RenaultClio 1.0 TCe 100 RS Line 5dr
# Saving: RenaultClio 1.0 TCe 100 RS Line 5dr
# Saving: RenaultClio 1.0 TCe 100 RS Line 5dr
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: not given
# Saving: not given
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: RenaultClio 1.0 TCe 100 Iconic 5dr
# Saving: RenaultClio 1.0 TCe 100 Play 5dr
# Saving: RenaultClio 1.0 TCe 100 Play 5dr
# Saving: RenaultClio 1.0 TCe 100 Play 5dr
# Saving: RenaultClio 1.0 TCe 100 Play 5dr
# Saving: RenaultClio 1.2 TCE Dynamique S Nav 5dr Auto
# Saving: not given
# Saving: RenaultClio 1.5 dCi 90 Dynamique S Nav 5dr Auto
# Saving: FordFiesta 1.0 EcoBoost Zetec 5dr Auto
# Saving: RenaultClio 1.2 TCE Dynamique S Nav 5dr
# Saving: RenaultClio 1.2 16V Dynamique Nav 5dr
# Saving: RenaultClio 1.5 dCi 90 Dynamique Nav 5dr Auto
# Saving: DaciaSandero Stepway 0.9 TCe SE Summit 5dr
# Saving: RenaultClio 1.2 16V Dynamique Nav 5dr
# Saving: DaciaSandero Stepway 0.9 TCe Comfort 5dr
# Saving: RenaultClio 0.9 TCE 90 Dynamique Nav 5dr
# Saving: RenaultClio 1.2 16V Dynamique Nav 5dr
# Saving: DaciaSandero Stepway 0.9 TCe Laureate 5dr
# Saving: not given
# Saving: DaciaSandero Stepway 0.9 TCe Ambiance 5dr
# Saving: DaciaSandero 1.0 SCe Essential 5dr
# Saving: DaciaSandero 0.9 TCe Ambiance 5dr
# Saving: BMW1 SERIES 116i SE 5dr Step Auto
# Saving: AUDIA1 1.4 TFSI S Line 3dr
# Saving: FORDFIESTA 1.4 Zetec 5dr Auto
# Saving: VOLKSWAGENPOLO 1.4 SEL 5dr DSG
# Saving: FORDFIESTA 1.4 Titanium 5dr Auto
# Saving: RENAULTCLIO 1.2 16V Dynamique MediaNav 5dr
# Saving: FORDFIESTA 1.25 82 Zetec 3dr
# Saving: VAUXHALLCORSA 1.2 Limited Edition 3dr
# Saving: NISSANMICRA 1.2 Acenta 5dr CVT
# Saving: VAUXHALLCORSA 1.0 ecoFLEX Excite 3dr [AC]
# Saving: HYUNDAII20 1.2 Classic 5dr
# Saving: HYUNDAII20 1.4 Active 5dr Auto
# Saving: KIAVENGA 1.6 2 5dr Auto
# Saving: FIATPANDA 1.2 Easy 5dr
# Saving: FORDFIESTA 1.25 Zetec 5dr [82]
# Saving: VAUXHALLCORSA 1.2i 16V [85] SXi 5dr [AC]
# Saving: FORDFIESTA 1.4 Ghia 5dr
# Saving: RENAULTCLIO 1.4 16V Privilege 5dr
# Saving: FORDFIESTA 1.25 Studio 3dr
# Saving: Mercedes-BenzA Class 1.6 A180 SE (s/s) 5dr
# Saving: Mercedes-BenzA Class 1.5 A180 CDI AMG Sport 7G-DCT 5dr
# Saving: Mercedes-BenzA Class 1.6 A180 SE (s/s) 5dr
# Saving: Mercedes-BenzA Class 1.6 A180 Sport 7G-DCT (s/s) 5dr
# Saving: BMW1 Series 1.5 118i Sport Sports Hatch (s/s) 5dr
# Saving: AudiA1 1.4 TFSI Sport Sportback (s/s) 5dr
# Saving: VolkswagenPolo 1.0 TSI SE (s/s) 5dr
# Saving: VolkswagenPolo 1.0 TSI SE (s/s) 5dr
# Saving: VolkswagenPolo 1.0 TSI Beats (s/s) 5dr
# Saving: not given
# Saving: AudiA1 1.0 TFSI Sport (s/s) 3dr
# Saving: BMW1 Series 1.5 118i Sport (s/s) 5dr
# Saving: not given
# Saving: AudiA1 1.4 TFSI Sport (s/s) 3dr
# Saving: VolkswagenPolo 1.2 TSI Match Edition (s/s) 3dr
# Saving: KiaPicanto 1.25 Sport 5dr
# Saving: ToyotaAuris VVT-I DESIGN
# Saving: HyundaiI10 SE
# Saving: FordFiesta ZETEC
# Saving: VauxhallCorsa ENERGY
# Saving: NissanMicra S
# Saving: MercedesA Class A 180 D SE
# Saving: ToyotaAuris VVT-I BUSINESS EDITION TOURING SPORTS
# Saving: CitroenDS3 DSTYLE
# Saving: RenaultClio DYNAMIQUE NAV TCE
# Saving: VauxhallCorsa ENERGY AC ECOFLEX
# Saving: VauxhallCorsa ENERGY A/C ECOFLEX
# Saving: FordFiesta ZETEC
# Saving: ToyotaAuris T4
# Saving: ToyotaAuris T4
# Saving: MitsubishiMirage 3
# Saving: VauxhallCorsa EXCLUSIV AC
# Saving: VauxhallCorsa LIMITED EDITION
# Saving: Peugeot208 E-HDI ACTIVE
# Saving: ToyotaAuris T SPIRIT VVT-I MM
# Saving: VauxhallCorsa SE
# Saving: ToyotaAuris TR VVT-I MMT
# Saving: VauxhallCorsa S ECOFLEX
# Saving: VauxhallCorsa EXCITE AC
# Saving: ToyotaAuris VALVEMATIC SR
# Saving: Peugeot208 ACCESS PLUS
# Saving: RenaultClio DYNAMIQUE MEDIANAV
# Saving: KiaPicanto 1
# Saving: ToyotaYaris ZINC MMT
# Saving: FordFiesta ZETEC
# Saving: ToyotaAYGO VVT-I BLUE
# Saving: VolkswagenPolo MATCH (70BHP)
# Saving: VauxhallCorsa BREEZE
# Saving: ToyotaYaris VVTI T2
# Saving: VolkswagenPolo SEL TDI
# Saving: VauxhallCorsa DESIGN 16V
# Saving: ToyotaYaris VVTI T SPIRIT
# Saving: not given
# Saving: MercedesA Class A150 CLASSIC SE
# Saving: NissanPixo N-TEC
# Saving: ToyotaYaris VVTI T2
# Saving: Peugeot207 SW S
# Saving: NissanMicra INITIA
# Saving: VolkswagenPolo 1.2 TSI Match (s/s) 5dr
# Saving: VolkswagenPolo 1.2 TSI BlueMotion Tech SEL (s/s) 3dr
# Saving: BMW1 Series 1.6 116i Sport Sports Hatch (s/s) 5dr
# Saving: SKODAFabia 1.2 TSI Colour Edition (s/s) 5dr
# Saving: ToyotaYaris 1.5 VVT-h Icon E-CVT 5dr
# Saving: SKODAFabia 1.0 SE (s/s) 5dr
# Saving: FordFiesta 1.0 EcoBoost Zetec (s/s) 5dr
# Saving: FordFiesta 1.0 T EcoBoost Zetec S (s/s) 3dr
# Saving: Volkswagenup! 1.0 Move up! ASG 5dr
# Saving: SKODAFabia 1.2 TSI SE 5dr
# Saving: Mercedes-BenzA-Class A200d Sport Premium 5dr Auto
# Saving: Mercedes-BenzA-Class A180d AMG Line Premium 4dr Auto
# Saving: Mercedes-BenzA-Class A180d AMG Line Premium 5dr Auto
# Saving: Mercedes-BenzA-Class A180d Sport 4dr Auto
# Saving: Mercedes-BenzA-Class A200 AMG Line 5dr Auto
# Saving: Mercedes-BenzA-Class A200 AMG Line Premium 5dr Auto
# Saving: Mercedes-BenzA-Class A200 AMG Line Premium 5dr Auto
# Saving: Mercedes-BenzA-Class A200 AMG Line Premium 5dr Auto
# Saving: Mercedes-BenzA-Class A180d AMG Line Premium 5dr Auto
# Saving: Mercedes-BenzA-Class A180d AMG Line Executive 5dr Auto
# Saving: Mercedes-BenzA-Class A180 Sport Executive 5dr Auto
# Saving: Mercedes-BenzA-Class A200d Sport Executive 5dr Auto
# Saving: Mercedes-BenzA-Class A200d Sport Executive 5dr Auto
# Saving: Mercedes-BenzA-Class A180D Amg Line Executive 5Dr Auto
# Saving: Mercedes-BenzA-Class A200d Sport Executive 5dr Auto
# Saving: Mercedes-BenzA-Class A180d Sport Executive 5dr Auto
# Saving: Mercedes-BenzA-Class A200 AMG Line 5dr Auto
# Saving: Mercedes-BenzA-Class A180 Sport 5dr Auto
# Saving: Mercedes-BenzA-Class A180d Sport Executive 5dr Auto
# Saving: Mercedes-BenzA-Class A180d Sport Executive 5dr Auto
# Saving: Mercedes-BenzA-Class A180d Sport Executive 5dr Auto
# Saving: Mercedes-BenzA-Class A180d Sport Executive 5dr Auto
# Saving: Mercedes-BenzA-Class A180d Sport Executive 5dr Auto
# Saving: Mercedes-BenzA-Class A180d Sport 5dr Auto
# Saving: Mercedes-BenzA-Class A180d Sport 5dr Auto
# Saving: Mercedes-BenzA-Class A180d Sport Executive 5dr Auto
# Saving: Mercedes-BenzA-Class A180d Sport 5dr Auto
# Saving: Mercedes-BenzA-Class A180d Sport 5dr Auto
# Saving: Mercedes-BenzA-Class A180d Sport 5dr Auto
# Saving: Mercedes-BenzA-Class A180 SE 5dr
# Saving: Mercedes-BenzA-Class A180d AMG Line 5dr
# Saving: Mercedes-BenzA-Class A180 AMG Line Premium 5dr
# Saving: Mercedes-BenzA-Class A180 AMG Line Premium 5dr
# Saving: Mercedes-BenzA-Class A200d AMG Line Premium 5dr
# Saving: Mercedes-BenzA-Class A180d AMG Line Premium 5dr Auto
# Saving: Mercedes-BenzA-Class A180d AMG Line Premium 5dr Auto
# Saving: Mercedes-BenzA-Class A200d AMG Line 5dr
# Saving: Mercedes-BenzA-Class A160 AMG Line 5dr
# Saving: Mercedes-BenzA-Class A180d Sport 5dr Auto
# Saving: Mercedes-BenzA-Class A180 AMG Line 5dr
# Saving: Mercedes-BenzA-Class A180 Sport 5dr Auto
# Saving: VauxhallCorsa 1.2 Turbo SRi Nav Premium 5dr Petrol Hatchback
# Saving: CitroenC3 Aircross 1.2 PureTech Flair 5dr Petrol Hatchback
# Saving: CitroenC3 Aircross 1.2 PureTech 110 Feel 5dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 SE 5dr Auto Petrol Hatchback
# Saving: VauxhallCorsa 1.4 [75] Griffin 5dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 SE 5dr Auto Petrol Hatchback
# Saving: VauxhallAdam 1.2i Griffin 3dr Petrol Hatchback
# Saving: VolkswagenPolo 1.2 TSI Match Edition 5dr Petrol Hatchback
# Saving: VolkswagenPolo 1.0 Match Edition 5dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 Griffin 3dr Petrol Hatchback
# Saving: ToyotaYaris 1.5 VVT-i Icon Tech 5dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 [75] Griffin 5dr Petrol Hatchback
# Saving: FordFiesta 1.0 EcoBoost Zetec 3dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 [75] Griffin 3dr Petrol Hatchback
# Saving: CitroenC3 1.2 PureTech 82 Feel 5dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 SRi 5dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 SRi 5dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 [75] Griffin 3dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 SRi Vx-line 5dr Petrol Hatchback
# Saving: NissanMicra 1.0 Acenta 5dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 [75] Energy 5dr [AC] Petrol Hatchback
# Saving: VauxhallAdam 1.2i Energised 3dr Petrol Hatchback
# Saving: VauxhallAdam 1.2i Slam 3dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 [75] Sport 3dr [AC] Petrol Hatchback
# Saving: VauxhallCorsa 1.4 ecoFLEX SRi 5dr Petrol Hatchback
# Saving: VauxhallAdam 1.2i Energised 3dr Petrol Hatchback
# Saving: VauxhallAdam 1.2i Energised 3dr Petrol Hatchback
# Saving: Hyundaii20 1.2 S Air 5dr Petrol Hatchback
# Saving: FordKA+ 1.2 85 Zetec 5dr Petrol Hatchback
# Saving: VauxhallViva 1.0 SL 5dr Petrol Hatchback
# Saving: VauxhallViva 1.0 SE 5dr [A/C] Petrol Hatchback
# Saving: not given
# Saving: ToyotaYaris 1.5 VVT-h Excel E-CVT 5dr (15in Alloy)
# Saving: ToyotaAuris 1.8 VVT-h Excel e-CVT HSD 5dr
# Saving: ToyotaAYGO 1.0 VVT-i x-play x-shift 5dr
# Saving: Hyundaiix20 1.6 Style 5dr
# Saving: SuzukiSwift 1.2 SZ4 5dr
# Saving: FordFiesta 1.0 EcoBoost Zetec (s/s) 5dr
# Saving: Peugeot208 1.2 VTi PureTech Allure 5dr
# Saving: MINIConvertible 1.6 Cooper S 2dr
# Saving: KiaVenga 1.6 3 5dr
# Saving: KiaVenga 1.4 TD 2 5dr
# Saving: NissanPixo 1.0 Acenta 5dr
# Saving: VauxhallCorsa 1.4 i 16v Design 5dr (a/c)
# Saving: DaciaSandero 1.2 16v Ambiance 5dr
# Saving: FordKa 1.2 Studio 3dr
# Saving: VauxhallCorsa 1.2 i 16v Exclusiv 5dr
# Saving: VolkswagenPolo 1.2 Match 5dr
# Saving: Hyundaii10 1.2 Classic 5dr
# Saving: BMW120d M SPORT
# Saving: VolkswagenPolo BLUEGT DSG
# Saving: MINIOne ONE D BAKER STREET
# Saving: MazdaMazda2 SPORT NAV
# Saving: FordFiesta ZETEC
# Saving: BMW1 SERIES 116i SPORT
# Saving: AudiA1 TFSI SPORT
# Saving: AudiA1 TFSI SPORT
# Saving: ToyotaAYGO VVT-I FIRE
# Saving: NissanMicra 1.0 IG-T 100 Tekna 5dr Xtronic
# Saving: NissanMicra 0.9 IG-T Tekna 5dr [Leather]
# Saving: NissanMicra 0.9 IG-T Tekna 5dr [Leather]
# Saving: NissanMicra 0.9 IG-T Acenta 5dr [Vision Pack]
# Saving: NissanMicra 0.9 IG-T Acenta 5dr [Vision Pack]
# Saving: NissanMicra 0.9 IG-T Acenta 5dr [Vision Pack]
# Saving: NissanMicra 0.9 IG-T Acenta 5dr [Vision Pack]
# Saving: NissanMicra 0.9 IG-T Acenta 5dr [Vision Pack]
# Saving: MercedesA Class A 180 D SPORT
# Saving: MercedesA Class A 200 D SPORT EXECUTIVE
# Saving: ToyotaAuris VVT-I ICON TOURING SPORTS
# Saving: BMW1 SERIES 116d SPORT
# Saving: ToyotaAuris VVT-I ICON TECH
# Saving: ToyotaAuris VVT-I ICON TSS - - - - S O L D - - -
# Saving: AudiA1 TFSI SPORT
# Saving: VolkswagenPolo SE TSI - - - - S O L D - - -
# Saving: VolkswagenPolo MATCH
# Saving: VolkswagenUp MOVE UP
# Saving: ToyotaAuris VALVEMATIC SR
# Saving: VolkswagenPolo 1.2 TSI BlueMotion Tech SEL DSG (s/s) 5dr
# Saving: ToyotaAYGO 1.0 VVT-i x-cite x-shift 5dr EU5
# Saving: SuzukiSwift 1.2 SZ4 AT 5dr (+Nav)
# Saving: ToyotaYaris 1.33 Icon+ M-Drive S 5dr
# Saving: ToyotaAuris 1.8 T Spirit CVT 5dr
# Saving: FordFiesta 1.25 Zetec 3dr
# Saving: not given
# Saving: Peugeot208 1.2 PureTech Active 5dr
# Saving: Hyundaii20 1.2 Style 5dr
# Saving: FordFiesta 1.4 Zetec 5dr
# Saving: ToyotaAYGO 1.0 VVT-i Ice 5dr
# Saving: ToyotaAYGO 1.0 VVT-i Platinum 5dr
# Saving: Hyundaii20 1.2 Comfort 5dr
# Saving: ToyotaYaris 1.3 VVT-i SR 5dr
# Saving: Mercedes-BenzA Class 1.5 A150 Classic SE 5dr
# Saving: VauxhallCorsa 1.2 SE 5dr Petrol Hatchback
# Saving: FordFiesta 1.0 EcoBoost ST-Line X 5dr Auto Petrol Hatchback
# Saving: VauxhallCorsa 1.4 Energy 5dr [AC] Auto Petrol Hatchback
# Saving: VauxhallCorsa 1.4 SE 5dr Auto Petrol Hatchback
# Saving: VauxhallCorsa 1.4 Energy 5dr [AC] Auto Petrol Hatchback
# Saving: VauxhallCorsa 1.4 Griffin 5dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 Elite 5dr Auto Petrol Hatchback
# Saving: VauxhallCorsa 1.4 SE 5dr Auto Petrol Hatchback
# Saving: VauxhallCorsa 1.4 Griffin 3dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 SE 5dr Auto Petrol Hatchback
# Saving: VauxhallCorsa 1.4 SE 5dr Auto Petrol Hatchback
# Saving: VauxhallCorsa 1.4 [75] Griffin 3dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 [75] Griffin 3dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 Energy 5dr [AC] Petrol Hatchback
# Saving: VauxhallCorsa 1.4 [75] Griffin 3dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 [75] Active 3dr Petrol Hatchback
# Saving: Hyundaiix20 1.6 SE 5dr Auto Petrol Hatchback
# Saving: VauxhallCorsa 1.4 Energy 3dr [AC] Petrol Hatchback
# Saving: VauxhallAdam 1.2i Energised 3dr Petrol Hatchback
# Saving: VauxhallAdam 1.2i Energised 3dr Petrol Hatchback
# Saving: VauxhallAdam 1.2i Energised 3dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 Limited Edition 5dr Petrol Hatchback
# Saving: VauxhallCorsa 1.2 Energy 5dr [AC] Petrol Hatchback
# Saving: VauxhallCorsa 1.4 [75] Griffin 5dr Petrol Hatchback
# Saving: VauxhallCorsa 1.4 [75] ecoFLEX Energy 3dr [AC] Petrol Hatchback
# Saving: VauxhallCorsa 1.4 [75] Energy 5dr [AC] Petrol Hatchback
# Saving: VauxhallCorsa 1.4 [75] Energy 3dr [AC] Petrol Hatchback
# Saving: VauxhallCorsa 1.4 [75] ecoFLEX Energy 3dr [AC] Petrol Hatchback
# Saving: VauxhallCorsa 1.4 Limited Edition 5dr Petrol Hatchback
# Saving: MercedesA Class A 180 D AMG LINE EXECUTIVE
# Saving: VauxhallCorsa LIMITED EDITION
# Saving: Mercedes-BenzA Class 2.1 A200d AMG Line (Executive) (s/s) 5dr
# Saving: not given
# Saving: VauxhallCorsa 1.6i Turbo VXR 3dr
# Saving: VolkswagenPolo 1.2 Match 3dr
# Saving: Hyundaii10 1.0 SE 5dr
# Saving: Peugeot208 1.4 VTi Active 3dr
# Saving: MINIConvertible 1.6 Cooper S 2dr
# Saving: MINIConvertible 1.6 Cooper 2dr
# Saving: MercedesA Class A 200 AMG LINE
# Saving: MercedesA Class A 180 D SPORT
# Saving: MercedesA Class A 180 D SPORT PREMIUM- - - SOLD- - -
# Saving: MercedesA Class A 160 SE
# Saving: MercedesA Class A 180 SPORT
# Saving: VolkswagenPolo SE TSI
# Saving: SkodaCitigo SE GREENTECH
# Saving: Peugeot208 50kWh Allure Auto 5dr
# Saving: Peugeot208 50kWh Allure Auto 5dr
# Saving: Peugeot208 50kWh Allure Auto 5dr
# Saving: Peugeot208 50kWh Allure Premium Auto 5dr
# Saving: Peugeot208 1.2 PureTech Active (s/s) 5dr
# Saving: CitroenC3 Aircross 1.2 PureTech Flair (s/s) 5dr
# Saving: Peugeot208 1.2 PureTech Active (s/s) 5dr
# Saving: Peugeot208 1.2 PureTech Active (s/s) 5dr
# Saving: CitroenC3 Aircross 1.2 PureTech Flair (s/s) 5dr
# Saving: CitroenC3 Aircross 1.2 PureTech Flair (s/s) 5dr
# Saving: CitroenC3 Aircross 1.2 PureTech Flair (s/s) 5dr
# Saving: Peugeot208 1.2 PureTech Tech Edition (s/s) 5dr
# Saving: Peugeot208 1.2 PureTech Signature (s/s) 5dr
# Saving: CitroenC3 1.2 PureTech Feel 5dr
# Saving: CitroenC3 1.2 PureTech Feel 5dr
# Saving: CitroenC3 1.2 PureTech Feel 5dr
# Saving: AudiA1 SPORTBACK TDI S LINE
# Saving: AudiA1 TDI S LINE
# Saving: VolkswagenPolo MATCH SATNAV PARK SENSORS CARPLAY
# Saving: VolkswagenPolo BlueMotion Tech SE
# Saving: AudiA1 TFSI SPORT
# Saving: VolkswagenPolo MATCH
# Saving: VolkswagenPolo SE
# Saving: VolkswagenPolo MATCH EDITION
# Saving: VolkswagenPolo BlueMotion Tech SE
# Saving: HyundaiI10 SE
# Saving: NissanMicra ACENTA
# Saving: VolkswagenPolo BlueMotion Tech SE
# Saving: AudiA1 TDI SPORT ONE OF A KIND COLOUR!
# Saving: KiaPicanto 2
# Saving: VolkswagenPolo MATCH
# Saving: VolkswagenPolo MATCH EDITION
# Saving: VolkswagenPolo MATCH EDITION
# Saving: VauxhallADAM GLAM
# Saving: ToyotaYaris D-4D TR
# <bound method NDFrame.head of                                                   name    price mileage  year  \
# 0                           MINIClubman COOPER CLASSIC  £17,950   7,000  2019
# 1                MINICooper Convertible COOPER CLASSIC  £16,750   6,000  2019
# 2                          AudiA1 SPORTBACK TFSI SPORT  £11,950  25,000  2017
# 3    BMW1 Series 1.6 116i M Sport Sports Hatch (s/s...   £8,795  46,000  2014
# 4                       BMW1 Series 2.0 116i Sport 3dr   £3,495  85,000  2010
# ..                                                 ...      ...     ...   ...
# 375                               VolkswagenPolo MATCH   £5,980  40,000  2013
# 376                       VolkswagenPolo MATCH EDITION   £5,780  62,000  2014
# 377                       VolkswagenPolo MATCH EDITION   £5,780  66,000  2014
# 378                                  VauxhallADAM GLAM   £4,980  39,000  2013
# 379                                ToyotaYaris D-4D TR   £4,180  75,000  2013
#
#        fuel engine_size  emission
# 0    Petrol       1.5 L  130 g/km
# 1    Petrol       1.5 L  118 g/km
# 2    Petrol       1.4 L  119 g/km
# 3    Petrol       1.6 L  131 g/km
# 4    Petrol       2.0 L  143 g/km
# ..      ...         ...       ...
# 375  Petrol       1.2 L  128 g/km
# 376  Petrol       1.2 L  128 g/km
# 377  Petrol       1.2 L  128 g/km
# 378  Petrol       1.4 L  129 g/km
# 379  Petrol       1.4 L  104 g/km
#
# [380 rows x 7 columns]>

# %%
df.head(30)
# Out:
#                                                  name    price mileage  year  \
# 0                          MINIClubman COOPER CLASSIC  £17,950   7,000  2019
# 1               MINICooper Convertible COOPER CLASSIC  £16,750   6,000  2019
# 2                         AudiA1 SPORTBACK TFSI SPORT  £11,950  25,000  2017
# 3   BMW1 Series 1.6 116i M Sport Sports Hatch (s/s...   £8,795  46,000  2014
# 4                      BMW1 Series 2.0 116i Sport 3dr   £3,495  85,000  2010
# 5                                           not given   £3,195  95,000  2013
# 6                              BMW1 SERIES 120i SPORT  £15,250  18,000  2016
# 7     FordFiesta 5Dr ST-Line X Edition 1.0 125PS Auto  £19,499   2,383  2020
# 8            FordFiesta 5Dr Titanium 1.0 Hybrid 125PS  £17,699     598  2020
# 9                       FordFiesta 5Dr ST-2 1.5 200PS  £17,499   6,349  2019
# 10           FordFiesta 5Dr Titanium 1.0 Hybrid 125PS  £16,499   3,256  2020
# 11    FordFiesta 5Dr ST-Line Edition 1.0 Hybrid 125PS  £16,499       7  2020
# 12    FordFiesta Vignale Fiesta 5Dr Vignale 1.0 140PS  £15,999   5,886  2019
# 13  FordFiesta Vignale Fiesta 5Dr Vignale Edition ...  £14,799   5,801  2018
# 14                  FordFiesta 5Dr Active X 1.0 100PS  £14,299  10,872  2019
# 15                 FordFiesta 5Dr ST-Line X 1.0 125PS  £14,000  12,981  2019
# 16                   FordFiesta 5Dr ST-Line 1.0 125PS  £13,499   5,742  2020
# 17                 FordFiesta 5Dr ST-Line X 1.0 125PS  £13,399   8,614  2019
# 18                  FordFiesta 5Dr Active X 1.0 125PS  £13,000   7,432  2018
# 19                  FordFiesta 5Dr Titanium 1.0 100PS  £11,899   7,522  2019
# 20                  FordFiesta 5Dr Titanium 1.0 100PS  £11,399  12,937  2019
# 21                   FordFiesta 3Dr ST-Line 1.0 140PS  £11,000  20,760  2018
# 22                FordFiesta 5Dr Zetec 1.0 100PS Auto  £10,899  26,664  2018
# 23                FordFiesta 5Dr Zetec 1.0 100PS Auto  £10,699  33,098  2018
# 24                  FordFiesta 5Dr Titanium 1.0 125PS  £10,599  12,271  2017
# 25                FordFiesta 3Dr Zetec 1.0 100PS Auto  £10,299  18,263  2017
# 26                      FordFiesta 5Dr Zetec 1.1 85PS  £10,000   9,361  2018
# 27                      FordFiesta 3Dr Zetec 1.1 85PS   £9,299   8,411  2018
# 28                     FordFiesta 5Dr Zetec 1.0 100PS   £9,199  21,582  2017
# 29                      FordFiesta 5Dr Zetec 1.1 85PS   £9,199  13,062  2017
#
#       fuel engine_size  emission
# 0   Petrol       1.5 L  130 g/km
# 1   Petrol       1.5 L  118 g/km
# 2   Petrol       1.4 L  119 g/km
# 3   Petrol       1.6 L  131 g/km
# 4   Petrol       2.0 L  143 g/km
# 5   Petrol       1.6 L  127 g/km
# 6   Petrol       1.6 L  133 g/km
# 7   Petrol       1.0 L  133 g/km
# 8   Petrol       1.0 L  115 g/km
# 9   Petrol       1.5 L  136 g/km
# 10  Petrol       1.0 L  115 g/km
# 11  Petrol       1.0 L  118 g/km
# 12  Petrol       1.0 L  112 g/km
# 13  Petrol       1.0 L  111 g/km
# 14  Petrol       1.0 L  113 g/km
# 15  Petrol       1.0 L  108 g/km
# 16  Petrol       1.0 L  108 g/km
# 17  Petrol       1.0 L  111 g/km
# 18  Petrol       1.0 L  113 g/km
# 19  Petrol       1.0 L  110 g/km
# 20  Petrol       1.0 L  110 g/km
# 21  Petrol       1.0 L  112 g/km
# 22  Petrol       1.0 L  125 g/km
# 23  Petrol       1.0 L  125 g/km
# 24  Petrol       1.0 L   98 g/km
# 25  Petrol       1.0 L  118 g/km
# 26  Petrol       1.1 L  114 g/km
# 27  Petrol       1.1 L  114 g/km
# 28  Petrol       1.0 L   97 g/km
# 29  Petrol       1.1 L  101 g/km

# %% [markdown]
# # FINAL DATA

# %%
df
# Out:
#                                                   name    price mileage  year  \
# 0                           MINIClubman COOPER CLASSIC  £17,950   7,000  2019
# 1                MINICooper Convertible COOPER CLASSIC  £16,750   6,000  2019
# 2                          AudiA1 SPORTBACK TFSI SPORT  £11,950  25,000  2017
# 3    BMW1 Series 1.6 116i M Sport Sports Hatch (s/s...   £8,795  46,000  2014
# 4                       BMW1 Series 2.0 116i Sport 3dr   £3,495  85,000  2010
# ..                                                 ...      ...     ...   ...
# 375                               VolkswagenPolo MATCH   £5,980  40,000  2013
# 376                       VolkswagenPolo MATCH EDITION   £5,780  62,000  2014
# 377                       VolkswagenPolo MATCH EDITION   £5,780  66,000  2014
# 378                                  VauxhallADAM GLAM   £4,980  39,000  2013
# 379                                ToyotaYaris D-4D TR   £4,180  75,000  2013
#
#        fuel engine_size  emission
# 0    Petrol       1.5 L  130 g/km
# 1    Petrol       1.5 L  118 g/km
# 2    Petrol       1.4 L  119 g/km
# 3    Petrol       1.6 L  131 g/km
# 4    Petrol       2.0 L  143 g/km
# ..      ...         ...       ...
# 375  Petrol       1.2 L  128 g/km
# 376  Petrol       1.2 L  128 g/km
# 377  Petrol       1.2 L  128 g/km
# 378  Petrol       1.4 L  129 g/km
# 379  Petrol       1.4 L  104 g/km
#
# [380 rows x 7 columns]
