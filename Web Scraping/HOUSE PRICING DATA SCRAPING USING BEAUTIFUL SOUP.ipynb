# %% [markdown]
# # HOUSE PRICING DATA SCRAPING USING BEAUTIFUL SOUP
# In this project, I scraped data from a rightmove.co.uk website using BeautifulSoup. I will use this data to analyse which part of London has the costliest houses.
#
# For scraping data from this website, I'll perform the following tasks:
#
# [**Task 1**](#task1): Importing the libraries
#
# [**Task 2**](#task2): Creating the base url and choosing the header
#
# [**Task 3**](#task3): Extracting product links on the first page
#
# [**Task 4**](#task4): Extracting product links on all the pages
#
# [**Task 5**](#task5): Extracting information of the first product
#
# [**Task 6**](#task6): Extracting information of all the products

# %% [markdown]
# <a id='task1'></a>
# # Task 1: Importing the libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# <a id='task2'></a>
# # Task 2: Creating the base url and choosing the header

# %%
base_url = 'https://www.rightmove.co.uk'

# %%
header = {
    'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.157 Safari/537.36"
}

# %% [markdown]
# <a id='task3'></a>
# # Task 3: Extracting product links on the first page

# %%
source = requests.get('https://www.rightmove.co.uk/property-for-sale/find.html?searchType=SALE&locationIdentifier=REGION%5E87490&insId=1&radius=0.0&minPrice=&maxPrice=&minBedrooms=&maxBedrooms=&displayPropertyType=&maxDaysSinceAdded=&_includeSSTC=on&sortByPriceDescending=&primaryDisplayPropertyType=&secondaryDisplayPropertyType=&oldDisplayPropertyType=&oldPrimaryDisplayPropertyType=&newHome=&auction=false')
soup = BeautifulSoup(source.content, 'lxml')

# %%
productlist = soup.find_all('div', class_ = 'propertyCard-details')
print(productlist)
# Out:
# [<div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/72172317">
# <h2 class="propertyCard-title" itemprop="name">
#             2 bedroom apartment for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Damac Tower, SW8" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Damac Tower, SW8</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/77411832">
# <h2 class="propertyCard-title" itemprop="name">
#             Block of apartments for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Investment Opportunity in Mayfair W1J" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Investment Opportunity in Mayfair W1J</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/97973531">
# <h2 class="propertyCard-title" itemprop="name">
#             12 bedroom terraced house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Upper Grosvenor Street, London, W1K" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Upper Grosvenor Street, London, W1K</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/97872269">
# <h2 class="propertyCard-title" itemprop="name">
#             12 bedroom town house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Upper Grosvenor Street, London, W1K" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Upper Grosvenor Street, London, W1K</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/98010533">
# <h2 class="propertyCard-title" itemprop="name">
#             Property for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Brook Street, London, W1K" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Brook Street, London, W1K</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/79055890">
# <h2 class="propertyCard-title" itemprop="name">
#             10 bedroom detached house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Merton Lane, London, N6" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Merton Lane, London, N6</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/99907829">
# <h2 class="propertyCard-title" itemprop="name">
#             6 bedroom terraced house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="South Street, Mayfair, London, W1K" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>South Street, Mayfair, London, W1K</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/89685296">
# <h2 class="propertyCard-title" itemprop="name">
#             6 bedroom house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="South Street, Mayfair W1K" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>South Street, Mayfair W1K</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/74956453">
# <h2 class="propertyCard-title" itemprop="name">
#             10 bedroom detached house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Merton Lane, London, N6" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Merton Lane, London, N6</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/77223961">
# <h2 class="propertyCard-title" itemprop="name">
#             Property for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Princes Gate, London, SW7" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Princes Gate, London, SW7</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/96434144">
# <h2 class="propertyCard-title" itemprop="name">
#             7 bedroom terraced house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Ilchester Place, Holland Park, London, W14" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Ilchester Place, Holland Park, London, W14</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/102076454">
# <h2 class="propertyCard-title" itemprop="name">
#             3 bedroom apartment for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="One Hyde Park, Knightsbridge" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>One Hyde Park, Knightsbridge</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/102229220">
# <h2 class="propertyCard-title" itemprop="name">
#             7 bedroom property for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Cleveland Row, St James's, SW1A" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Cleveland Row, St James's, SW1A</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/92781332">
# <h2 class="propertyCard-title" itemprop="name">
#             10 bedroom detached house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Upper Phillimore Gardens, Kensington, London, W8" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Upper Phillimore Gardens, Kensington, London, W8</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/70700242">
# <h2 class="propertyCard-title" itemprop="name">
#             10 bedroom detached house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Upper Phillimore Gardens, London, W8" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Upper Phillimore Gardens, London, W8</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/97153931">
# <h2 class="propertyCard-title" itemprop="name">
#             6 bedroom terraced house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Culross Street, Mayfair, London, W1K" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Culross Street, Mayfair, London, W1K</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/97132076">
# <h2 class="propertyCard-title" itemprop="name">
#             6 bedroom terraced house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Culross Street, Mayfair, London, W1K" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Culross Street, Mayfair, London, W1K</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/77413920">
# <h2 class="propertyCard-title" itemprop="name">
#             7 bedroom detached house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Phillimore Gardens, Kensington, London" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Phillimore Gardens, Kensington, London</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/83798710">
# <h2 class="propertyCard-title" itemprop="name">
#             8 bedroom detached house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Elsworthy Road, London, NW3" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Elsworthy Road, London, NW3</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/80794139">
# <h2 class="propertyCard-title" itemprop="name">
#             8 bedroom detached house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Elsworthy Road, Primrose Hill, London, NW3" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Elsworthy Road, Primrose Hill, London, NW3</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/94277630">
# <h2 class="propertyCard-title" itemprop="name">
#             3 bedroom flat for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="One Hyde Park, Knightsbridge, London, SW1X" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>One Hyde Park, Knightsbridge, London, SW1X</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/85982015">
# <h2 class="propertyCard-title" itemprop="name">
#             6 bedroom town house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Chapel Street, Belgravia SW1X" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Chapel Street, Belgravia SW1X</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/84680905">
# <h2 class="propertyCard-title" itemprop="name">
#             8 bedroom detached house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="St Johns Wood Park, London, NW8" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>St Johns Wood Park, London, NW8</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/64810998">
# <h2 class="propertyCard-title" itemprop="name">
#             8 bedroom house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Hamilton Terrace, London, NW8" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Hamilton Terrace, London, NW8</span>
# </address>
# </a>
# </div>, <div class="propertyCard-details">
# <a class="propertyCard-link" data-test="property-details" href="/properties/73552941">
# <h2 class="propertyCard-title" itemprop="name">
#             6 bedroom detached house for sale        </h2>
# <address class="propertyCard-address" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta content="Avenue Road, St. John's Wood, London, NW8" itemprop="streetAddress"/>
# <meta content="GB" itemprop="addressCountry"/>
# <span>Avenue Road, St. John's Wood, London, NW8</span>
# </address>
# </a>
# </div>]

# %%
productlinks = []
for item in productlist:
    for link in item.find_all('a', href = True, class_ = 'propertyCard-link'):
        print(link['href'])
# Out:
# /properties/72172317
# /properties/77411832
# /properties/97973531
# /properties/97872269
# /properties/98010533
# /properties/79055890
# /properties/99907829
# /properties/89685296
# /properties/74956453
# /properties/77223961
# /properties/96434144
# /properties/102076454
# /properties/102229220
# /properties/92781332
# /properties/70700242
# /properties/97153931
# /properties/97132076
# /properties/77413920
# /properties/83798710
# /properties/80794139
# /properties/94277630
# /properties/85982015
# /properties/84680905
# /properties/64810998
# /properties/73552941

# %%
for item in productlist:
    for link in item.find_all('a', href = True, class_ = 'propertyCard-link'):
        productlinks.append(base_url + link['href'])
print(len(productlinks))
# Out:
# 25

# %% [markdown]
# <a id='task4'></a>
# # Task 4: Extracting product links on all the pages

# %%
productlinks = []



for i in range(0,100,12):
    source = requests.get(f'https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%5E87490&index={i}&propertyTypes=&includeSSTC=false&mustHave=&dontShow=&furnishTypes=&keywords=')
    soup = BeautifulSoup(source.content, 'lxml')
    productlist = soup.find_all('div', class_ = 'propertyCard-details')
    for item in productlist:
        for link in item.find_all('a', href = True, class_ = 'propertyCard-link'):
            productlinks.append(base_url + link['href']+ '#/')
print(len(productlinks))
# Out:
# 225

# %% [markdown]
# <a id='task5'></a>
# # Task 5: Extracting information of the first product

# %%
testlink = 'https://www.rightmove.co.uk/properties/77411832#/'
r = requests.get(testlink, headers = header)
soup = BeautifulSoup(r.content, 'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en-GB" style="">
# <head>
# <meta charset="utf-8"/>
# <title>Block of apartments for sale in Investment Opportunity in Mayfair W1J</title>
# <meta content="width=device-width, shrink-to-fit=no, initial-scale=1.0, user-scalable=yes" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="Block of apartments for sale in Investment Opportunity in Mayfair W1J - Rightmove." name="description"/>
# <!-- Favicons -->
# <link href="//www.rightmove.co.uk/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <meta content="Rightmove" name="apple-mobile-web-app-title"/>
# <meta content="Rightmove" name="application-name"/>
# <meta content="#262637" name="theme-color"/>
# <meta content="app-id=323822803, app-argument=https://www.rightmove.co.uk/properties/77411832" name="apple-itunes-app"/>
# <meta content="Rightmove Property Search" name="smartbanner:title"/>
# <meta content="Rightmove" name="smartbanner:author"/>
# <meta content="FREE" name="smartbanner:price"/>
# <meta content=" - On the App Store" name="smartbanner:price-suffix-apple"/>
# <meta content=" - In Google Play" name="smartbanner:price-suffix-google"/>
# <meta content="//media.rightmove.co.uk/assets/a04c507a807f8bdd7543a397a71b0ac4/images/app-icon-192.png" name="smartbanner:icon-apple"/>
# <meta content="//media.rightmove.co.uk/assets/a04c507a807f8bdd7543a397a71b0ac4/images/app-icon-192.png" name="smartbanner:icon-google"/>
# <meta content="View" name="smartbanner:button"/>
# <meta content="https://apps.apple.com/gb/app/id323822803?pt=273054&amp;ct=msite&amp;mt=8" name="smartbanner:button-url-apple"/>
# <meta content="https://play.google.com/store/apps/details?id=com.rightmove.android" name="smartbanner:button-url-google"/>
# <meta content="android" name="smartbanner:enabled-platforms"/>
# <meta content="Close" name="smartbanner:close-label"/>
# <meta content="86400000" name="smartbanner:hide-ttl"/>
# <meta content="/" name="smartbanner:hide-path"/>
# <meta content="true" name="smartbanner:api"/>
# <link href="https://www.rightmove.co.uk/properties/77411832" rel="canonical"/>
# <meta content="https://www.rightmove.co.uk/properties/77411832" property="og:url"/>
# <meta content="Check out this Block of apartments for sale on Rightmove" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="Block of apartments for sale in Investment Opportunity in Mayfair W1J POA. Marketed by Wedgewood Estates, London" property="og:description"/>
# <meta content="https://media.rightmove.co.uk/103k/102385/77411832/102385_2584828_IMG_00_0000.jpeg" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/103k/102385/77411832/102385_2584828_IMG_01_0000.jpeg" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/103k/102385/77411832/102385_2584828_IMG_02_0000.jpeg" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/103k/102385/77411832/102385_2584828_IMG_03_0000.jpeg" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/103k/102385/77411832/102385_2584828_IMG_04_0000.jpeg" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/103k/102385/77411832/102385_2584828_IMG_05_0000.jpeg" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/103k/102385/77411832/102385_2584828_IMG_06_0000.jpeg" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/103k/102385/77411832/102385_2584828_IMG_07_0000.jpeg" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/103k/102385/77411832/102385_2584828_IMG_08_0000.jpeg" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/103k/102385/77411832/102385_2584828_IMG_09_0000.jpeg" property="og:image"/>
# <meta content="https://media.rightmove.co.uk/103k/102385/77411832/102385_2584828_IMG_10_0000.jpeg" property="og:image"/>
# <meta content="en_GB" property="og:locale"/>
# <meta content="Rightmove.co.uk" property="og:site_name"/>
# <meta content="rightmove.plc" property="fb:admins"/>
# <meta content="485764298115191" property="fb:app_id"/>
# <meta content="2911111" property="twitter:account_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://media.rightmove.co.uk/103k/102385/77411832/102385_2584828_IMG_00_0000.jpeg" name="twitter:image:src"/>
# <meta content="@rightmove" name="twitter:site"/>
# <meta content="https://www.rightmove.co.uk/properties/77411832" name="twitter:url"/>
# <meta content="Check out this Block of apartments for sale on Rightmove" name="twitter:title"/>
# <meta content="Block of apartments for sale in Investment Opportunity in Mayfair W1J POA. Marketed by Wedgewood Estates, London" name="twitter:description"/>
# <link as="font" crossorigin="" href="/ps/fonts/effra/Effra_WLatn_Md.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/ps/fonts/effra/Effra_WLatn_Rg.woff2" rel="preload" type="font/woff2"/>
# <style>
#         @font-face {
#             font-family: 'Effra';
#             src: url('/ps/fonts/effra/Effra_WLatn_Md.eot'); /* IE9 Compat Modes */
#             src: /* IE6-IE8 */ url('/ps/fonts/effra/Effra_WLatn_Md.eot?#iefix') format('embedded-opentype'),
#                 /* Super Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Md.woff2') format('woff2'),
#                 /* Pretty Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Md.woff') format('woff');
#             font-style: normal;
#             font-weight: 500;
#             font-display: swap;
#         }
#         @font-face {
#             font-family: 'Effra';
#             src: url('/ps/fonts/effra/Effra_WLatn_Rg.eot');
#             src: /* IE6-IE8 */ url('/ps/fonts/effra/Effra_WLatn_Rg.eot?#iefix') format('embedded-opentype'),
#                 /* Super Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Rg.woff2') format('woff2'),
#                 /* Pretty Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Rg.woff') format('woff');
#             font-style: normal;
#             font-weight: normal;
#             font-display: swap;
#         }
#     </style>
# <link as="style" data-chunk="shared" href="//media.rightmove.co.uk/assets/a04c507a807f8bdd7543a397a71b0ac4/shared.fbad9c5a8964969509f3.css" rel="preload"/>
# <link as="script" data-chunk="shared" href="//media.rightmove.co.uk/assets/a04c507a807f8bdd7543a397a71b0ac4/shared.fbad9c5a8964969509f3.js" rel="preload"/>
# <link data-chunk="shared" href="//media.rightmove.co.uk/assets/a04c507a807f8bdd7543a397a71b0ac4/shared.fbad9c5a8964969509f3.css" rel="stylesheet"/>
# <!-- Google Optimize -->
# <!-- Anti-flicker snippet (recommended)  -->
# <style>.async-hide { opacity: 0 !important} </style>
# <script>(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
#     h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#     (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#     })(window,document.documentElement,'async-hide','dataLayer',4000,
#     {'GTM-M5C7HFR':true});function gtag() {dataLayer.push(arguments)};</script>
# <script async="" onerror="dataLayer.hide.end &amp;&amp; dataLayer.hide.end()" src="https://www.googleoptimize.com/optimize.js?id=GTM-M5C7HFR"></script>
# <!-- End Google Optimize -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','rmDataLayer','GTM-T4524Q');</script>
# <!-- End Google Tag Manager -->
# </head>
# <body>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-T4524Q" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager -->
# <div aria-hidden="true" class="svg-sprite" style="height: 0; width: 0; overflow: hidden;">
# <svg height="0" style="position:absolute" width="0">
# <symbol id="rightmove-with-icon-logo" viewbox="0 0 3884 790">
# <g fill-rule="nonzero"><path d="M3833.103 492.675h-95.98l-95.395-80.762-95.771 80.762h-95.708c-13.475 0-26.134-5.25-35.659-14.791-9.525-9.534-14.754-22.213-14.737-35.692l.262-215.7c.017-13.3 5.154-25.854 14.459-35.367l2.07-1.917L3641.724 0l227.204 191.18c9.28 9.47 14.392 21.987 14.4 35.245l.263 215.68c.025 13.487-5.217 26.195-14.759 35.75-9.541 9.554-22.229 14.82-35.729 14.82zm-74.592-58.358h66.713l-.25-204.025-183.25-154.042-183.255 154.034-.241 204.033h66.412l117.167-98.804 116.704 98.804z" fill="#00deb6"></path><path d="M372.171 154.488c-5.492-4.58-11.779-8.075-18.85-10.521-7.062-2.45-14.367-3.671-21.904-3.671-7.538 0-14.842 1.22-21.913 3.67-7.062 2.447-13.429 5.942-19.083 10.522-5.654 4.562-10.13 10.35-13.42 17.375-3.3 7.008-4.95 14.916-4.95 23.725 0 8.816 1.65 16.65 4.95 23.5 3.29 6.841 7.766 12.637 13.42 17.366 5.654 4.73 12.02 8.234 19.083 10.521a71.118 71.118 0 0021.913 3.43 71.026 71.026 0 0021.904-3.43c7.071-2.287 13.358-5.791 18.85-10.52 5.492-4.73 9.892-10.526 13.196-17.367 3.292-6.85 4.946-14.684 4.946-23.5 0-8.809-1.654-16.717-4.946-23.725-3.304-7.025-7.704-12.813-13.196-17.375zm688.084 126.458c-19.846 0-39.446 3.558-58.783 10.658-19.346 7.109-34.871 17.267-46.571 30.509V143.488H845.73v490.28h109.93V448.53c0-10.288 1.532-19.959 4.582-29.038 3.059-9.054
# </symbol>
# <symbol id="rightmove-icon-logo" viewbox="0 0 2099 2138">
# <path d="M1879.272 2137.031h-416.317l-413.787-350.321-415.426 350.321H218.604c-58.45 0-113.366-22.77-154.683-64.154-41.317-41.35-63.983-96.363-63.92-154.813l1.145-935.638c.062-57.7 22.346-112.154 62.713-153.404l8.975-8.325L1049.134 0l985.539 829.247c40.237 41.091 62.416 95.379 62.45 152.883l1.15 935.542c.095 58.517-22.642 113.626-64.025 155.076-41.384 41.445-96.425 64.283-154.976 64.283zm-323.554-253.142h289.38l-1.084-884.984-794.88-668.171-794.88 668.138-1.05 885.017H541.28l508.217-428.567 506.221 428.567z" fill="#00deb6" fill-rule="nonzero"></path>
# </symbol>
# <symbol id="account-silhouette" viewbox="0 0 13.8 21.8">
# <circle cx="6.9" cy="5" r="5"></circle><path d="M12 13.6L8.7 12c-.5-.2-1.2-.4-1.8-.4s-1.3.2-1.8.4l-3.3 1.6c-1 .5-1.8 1.8-1.8 2.9v3.3c0 1.1.9 2 2 2h9.8c1.1 0 2-.9 2-2v-3.3c0-1.1-.8-2.4-1.8-2.9z"></path>
# </symbol>
# <symbol id="chevron-line" viewbox="0 0 16 16">
# <path d="M8 10.293l5.146-5.147a.5.5 0 0 1 .708.708l-5.5 5.5a.5.5 0 0 1-.708 0l-5.5-5.5a.5.5 0 1 1 .708-.708L8 10.293z"></path>
# </symbol>
# <symbol id="chevron" viewbox="0 0 7.6 4.1">
# <path d="M4 4L7.5.5c.2-.2.1-.5-.2-.5h-7C0 0-.1.3.1.5L3.6 4c.1.1.3.1.4 0z"></path>
# </symbol>
# <symbol id="camera" viewbox="0 0 16 13">
# <path d="M5 0v1h8.5A2.5 2.5 0 0116 3.5v8a1.5 1.5 0 01-1.5 1.5h-13A1.5 1.5 0 010 11.5v-8a2.5 2.5 0 012-2.45V0h3zm8.5 2h-11A1.5 1.5 0 001 3.5v8a.5.5 0 00.5.5h13a.5.5 0 00.5-.5v-8A1.5 1.5 0 0013.5 2zM8 4a3 3 0 110 6 3 3 0 010-6zm0 1a2 2 0 100 4 2 2 0 000-4zm6-1v1h-2V4h2z"></path>
# </symbol>
# <symbol id="no-camera" viewbox="0 0 16 16">
# <path d="M11.88 2l-1 1H2.5A1.5 1.5 0 001 4.5v8c0 .107.034.206.091.288l-.652.651-.057.06A1.494 1.494 0 010 12.5v-8a2.5 2.5 0 012-2.45V1h3v1h6.88zm3.448.795c.417.447.672 1.046.672 1.705v8a1.5 1.5 0 01-1.5 1.5H4.121l1-1H14.5a.5.5 0 00.5-.5v-8c0-.383-.143-.732-.38-.997l.708-.708zm-8.105 8.104l.903-.903a2 2 0 001.87-1.87l.903-.902a3.004 3.004 0 01-3.676 3.675zM5.102 8.778a3.004 3.004 0 013.676-3.676l-.902.902a2 2 0 00-1.872 1.872l-.902.902zm9.051-7.63a.5.5 0 01.707.706l-13.001 13a.5.5 0 01-.707-.708L14.153 1.147z"></path>
# </symbol>
# <symbol id="floorplan" viewbox="0 0 14 14">
# <path d="M13 7v5a1 1 0 01-1 1H6v1h6a2 2 0 002-2V2a2 2 0 00-2-2H2a2 2 0 00-2 2v10a2 2 0 002 2h2v-1H2a1 1 0 01-1-1v-2h7V9H1V2a1 1 0 011-1h2v5h1V1h7a1 1 0 011 1v4H8v1h5z"></path>
# </symbol>
# <symbol id="virtual-tour" viewbox="0 0 16 14">
# <path d="M12 0a4 4 0 014 4v6a4 4 0 01-4 4H4a4 4 0 01-4-4V4a4 4 0 014-4h8zm0 1H4a3 3 0 00-3 3v6a3 3 0 003 3h8a3 3 0 003-3V4a3 3 0 00-3-3zM6.765 4.076l4 2.5a.5.5 0 010 .848l-4 2.5A.5.5 0 016 9.5v-5a.5.5 0 01.765-.424zM7 5.402v3.196L9.557 7 7 5.402z"></path>
# </symbol>
# <symbol id="play-icon" viewbox="0 0 16 16">
# <g fill="none" fill-rule="evenodd">
# <path d="M4 1h8a4 4 0 014 4v6a4 4 0 01-4 4H4a4 4 0 01-4-4V5a4 4 0 014-4z" fill="#262637" opacity=".848"></path>
# <path d="M10.265 8.424l-4 2.5a.5.5 0 01-.765-.425V5.501a.5.5 0 01.765-.424l4 2.5a.5.5 0 010 .847z" fill="#FFF" fill-rule="nonzero"></path>
# </g>
# </symbol>
# <symbol id="arrow-left" viewbox="0 0 17 13">
# <path d="M2.707 7l5.147 5.146-.708.708L.793 6.5 7.146.146l.708.708L2.707 6H17v1z"></path>
# </symbol>
# <symbol id="close" viewbox="0 0 16 16">
# <path d="M7.293 8L1.146 1.854l.708-.708L8 7.293l6.146-6.147.708.708L8.707 8l6.147 6.146-.708.708L8 8.707l-6.146 6.147-.708-.708L7.293 8z"></path>
# </symbol>
# <symbol id="email" viewbox="0 0 16 16">
# <path d="M1.143 3H1v9a1 1 0 001 1h12a1 1 0 001-1V3h-.143L8 9 1.143 3zM0 2h16v10a2 2 0 01-2 2H2a2 2 0 01-2-2V2zm2.703 1L8 7.683 13.297 3H2.703z"></path>
# </symbol>
# <symbol id="earth" viewbox="0 0 16 16">
# <path d="M8 0a8 8 0 110 16A8 8 0 018 0zM3.459 2.673l.76.382a1.5 1.5 0 01.73 1.867l-.057.132-1.007 2.06a.5.5 0 00.149.62l.076.047 3.232 1.615a1.5 1.5 0 01.737 1.86l-.056.133-1.647 3.422a7 7 0 008.5-8.136l-.346.68a1.5 1.5 0 01-1.854.73l-.131-.056-1.189-.57a1.5 1.5 0 01-.691-1.894l.061-.131.458-.872a.5.5 0 00-.16-.62l-.077-.046-5.268-2.502a6.992 6.992 0 00-2.22 1.279zM1 8a7.002 7.002 0 004.413 6.506l1.71-3.551a.5.5 0 00-.152-.617l-.076-.047-3.232-1.615a1.5 1.5 0 01-.734-1.869l.057-.132 1.007-2.06a.5.5 0 00-.148-.62L3.77 3.95 2.71 3.415A6.973 6.973 0 001 8zm7-7c-.25 0-.495.013-.738.038l4.114 1.955a1.5 1.5 0 01.767 1.865l-.056.133-.476.908a.5.5 0 00.134.626l.093.058 1.138.544a.5.5 0 00.615-.15l.047-.075.818-1.612A7.002 7.002 0 008 1z"></path>
# </symbol>
# <symbol id="phone" viewbox="0 0 16 16">
# <path d="M2.53 2.975a2.842 2.842 0 00-.427 3.472l.578.963c1.308 2.18 3.84 4.713 6.02 6.021l.964.578a2.842 2.842 0 003.472-.428l1.414-1.414-2.828-2.828-1.83 1.83-.565-.161c-1.55-.44-3.498-2.31-4.04-3.827l-.306-.86L6.844 4.46l-2.9-2.9L2.53 2.976zm-.707-.707L3.237.854a1 1 0 011.414 0l2.9 2.899a1 1 0 010 1.414L6.136 6.58l.095.264c.432 1.213 2.131 2.85 3.37 3.2l1.414-1.413a1 1 0 011.415 0l2.828 2.828a1 1 0 010 1.414l-1.414 1.415a3.842 3.842 0 01-4.694.577l-.963-.577c-2.321-1.393-4.971-4.043-6.364-6.364l-.578-.963a3.842 3.842 0 01.578-4.694z"></path>
# </symbol>
# <symbol id="approx-location-circle" viewbox="0 0 320 320">
# <circle cx="160" cy="160" r="150" stroke-width="4"></circle>
# </symbol>
# <symbol id="map-pin" viewbox="0 0 12 16">
# <path d="M6 0a6 6 0 016 6c0 4-2 7.333-6 10-4-2.667-6-6-6-10a6 6 0 016-6zm0 1a5 5 0 00-5 5c0 3.46 1.639 6.368 5 8.784C9.361 12.368 11 9.46 11 6a5 5 0 00-5-5zm0 2a3 3 0 110 6 3 3 0 010-6zm0 1a2 2 0 100 4 2 2 0 000-4z"></path>
# </symbol>
# <symbol id="streetview" viewbox="0 0 15 16">
# <path d="M7.5 5A3.5 3.5 0 0111 8.5V11h-1v.054c2.97.318 5 1.16 5 2.408C15 15.029 11.664 16 7.5 16S0 15.029 0 13.462c0-1.248 2.032-2.09 5-2.408V11H4V8.5A3.5 3.5 0 017.5 5zM1 13.462C1 14.146 3.932 15 7.5 15s6.5-.854 6.5-1.538c0-.47-1.625-1.125-3.999-1.4L10 14H5v-1.939c-2.375.276-4 .93-4 1.4zM7.5 6a2.5 2.5 0 00-2.495 2.336L5 8.5V10h1v3h3v-3h1V8.5a2.5 2.5 0 00-2.336-2.495L7.5 6zm0-6a2.5 2.5 0 110 5 2.5 2.5 0 010-5zm0 1a1.5 1.5 0 100 3 1.5 1.5 0 000-3z"></path>
# </symbol>
# <symbol id="school" viewbox="0 0 16 12">
# <path d="M14.5 10.5a.5.5 0 110 1 .5.5 0 010-1zM8.211.047l7.5 3.5a.5.5 0 010 .906L15 4.785V9a.5.5 0 11-1 0V5.251l-1 .467v2.805c0 1.725-2.275 2.977-5 2.977s-5-1.252-5-2.977V5.719L.289 4.453a.5.5 0 010-.906l7.5-3.5a.5.5 0 01.422 0zM12 6.185L8.211 7.953l-.004.001L8 8.052l-.203-.095a.5.5 0 01-.008-.004L4 6.185v2.338C4 9.534 5.754 10.5 8 10.5s4-.966 4-1.977V6.185zM8 1.052L1.682 4 3 4.615l5 2.333 2.373-1.108L13 4.615l1-.467V4a.5.5 0 01.02-.138L8 1.052z"></path>
317.51-1.529A3.493 3.493 0 01.784 12.35L.352 10.62A.5.5 0 01.837 10h1.5V2.5a2.5 2.5 0 012.5-2.5zm8.36 11H1.477l.277 1.106A2.5 2.5 0 004.18 14h6.315c.39 0 .763-.09 1.096-.253l-.007-.02.128-.043a2.499 2.499 0 001.208-1.578L13.197 11zm-4.36-3a.5.5 0 110 1 .5.5 0 010-1zm-2 0a.5.5 0 110 1 .5.5 0 010-1zm-2 0a.5.5 0 110 1 .5.5 0 010-1zm3-1a.5.5 0 110 1 .5.5 0 010-1zm-2 0a.5.5 0 110 1 .5.5 0 010-1zm1-1a.5.5 0 110 1 .5.5 0 010-1zm0-3a1.5 1.5 0 00-1.414 1h2.829a1.5 1.5 0 00-1.415-1z"></path>
# </symbol>
# <symbol id="exclamation-circle" viewbox="0 0 16 16">
# <path d="M8 0a8 8 0 110 16A8 8 0 018 0zm0 1a7 7 0 100 14A7 7 0 008 1zm0 9a1 1 0 110 2 1 1 0 010-2zm-.066-6a.874.874 0 01.857 1.046L8 9l-.897-3.96A.852.852 0 017.933 4z"></path>
# </symbol>
# <svg id="facebook" viewbox="0 0 32 32">
# <g fill="none" fill-rule="evenodd">
# <path d="M32 16.094C32 7.206 24.837 0 16 0S0 7.206 0 16.094c0 8.033 5.851 14.692 13.5 15.9V20.746H9.437v-4.653H13.5V12.55c0-4.034 2.389-6.262 6.043-6.262 1.751 0 3.582.314 3.582.314v3.96h-2.018c-1.987 0-2.607 1.241-2.607 2.514v3.02h4.438l-.71 4.652H18.5v11.246c7.649-1.208 13.5-7.867 13.5-15.9" fill="#1877F2"></path>
# <path d="M22.083 20.956l.725-4.49H18.27v-2.914c0-1.228.634-2.426 2.667-2.426H23V7.303S21.127 7 19.337 7c-3.739 0-6.182 2.15-6.182 6.044v3.422H9v4.49h4.155v10.855a17.352 17.352 0 005.114 0V20.956h3.814" fill="#FFF"></path>
# </g>
# </svg>
# <symbol id="share" viewbox="0 0 14 14"><defs></defs>
# <path d="M11.5 0a2.5 2.5 0 11-1.967 4.043L4.92 6.368a2.504 2.504 0 01-.004 1.281l4.617 2.309a2.5 2.5 0 11-.447.894L4.467 8.543a2.5 2.5 0 11.01-3.074l4.608-2.32A2.503 2.503 0 0111.5 0zm0 10a1.5 1.5 0 100 3 1.5 1.5 0 000-3zm-9-4.5a1.5 1.5 0 100 3 1.5 1.5 0 000-3zm9-4.5a1.5 1.5 0 100 3 1.5 1.5 0 000-3z"></path>
# </symbol>
# <symbol id="twitter" viewbox="0 0 32 27"><defs></defs>
# <path d="M10.063 27c12.076 0 18.68-10.389 18.68-19.397 0-.295 0-.59-.019-.882A13.654 13.654 0 0032 3.193c-1.198.55-2.47.912-3.77 1.072a6.802 6.802 0 002.886-3.77 12.866 12.866 0 01-4.17 1.654C24.912-.098 21.679-.648 19.06.808c-2.62 1.455-3.973 4.554-3.3 7.559-5.28-.275-10.198-2.864-13.532-7.123-1.742 3.115-.852 7.1 2.033 9.1a6.334 6.334 0 01-2.98-.853v.087c0 3.245 2.204 6.04 5.267 6.683a6.32 6.32 0 01-2.964.117c.86 2.777 3.325 4.68 6.133 4.734a12.867 12.867 0 01-8.153 2.924A12.877 12.877 0 010 23.938a18.09 18.09 0 0010.063 3.057" fill="#1DA1F2" fill-rule="nonzero"></path>
3283594,2.79496355 Z M7.22345878,10.8985251 L8.12604085,9.99609216 C9.13010008,9.93365542 9.93347285,9.13038564 9.99607232,8.12636963 L10.8986531,7.22393796 C10.9647594,7.47147773 11,7.73162342 11,8 C11,9.65685425 9.65685425,11 8,11 C7.73145024,11 7.471142,10.9647139 7.22345878,10.8985251 Z M5.10175489,8.77758823 C5.03538565,8.52959162 5,8.26892819 5,8 C5,6.34314575 6.34314575,5 8,5 C8.26910138,5 8.52992735,5.03543124 8.77806734,5.10188316 L7.87602522,6.00377625 C6.87031249,6.0652873 6.06546981,6.87002688 6.0038002,7.87569196 L5.10175489,8.77758823 Z M14.1532742,1.1471686 C14.3485525,0.95192259 14.665135,0.951948744 14.860381,1.14722702 C15.055627,1.3425053 15.0556008,1.65908779 14.8603226,1.8543338 L1.8590326,14.8534758 C1.66375433,15.0487218 1.34717184,15.0486956 1.15192583,14.8534174 C0.956679811,14.6581391 0.956705965,14.3415566 1.15198424,14.1463106 L14.1532742,1.1471686 Z"></path>
# </symbol>
# <symbol id="copy-link" viewbox="0 0 26 30">
# <path d="M2 7v20a1 1 0 00.82.984L3 28h16v2H3a3 3 0 01-2.986-2.711L0 27V7h2zm21-7a3 3 0 013 3v20a3 3 0 01-3 3H7a3 3 0 01-3-3V3a3 3 0 013-3zm0 2H7a1 1 0 00-1 1v20a1 1 0 001 1h16a1 1 0 001-1V3a1 1 0 00-1-1z"></path>
# </symbol>
# <symbol id="check-circle" viewbox="0 0 16 16">
# <path d="M8 0a8 8 0 110 16A8 8 0 018 0zm0 1a7 7 0 100 14A7 7 0 008 1zM6.5 9.793l4.646-4.647.708.708L6.5 11.207 4.146 8.854l.708-.708L6.5 9.793z"></path>
# </symbol>
# <symbol id="whatsapp" viewbox="70 70 355 355">
# <defs>
# <lineargradient gradientunits="userSpaceOnUse" id="linear-gradient" x1="640.24" x2="640.24" y1="738.97" y2="332.78">
# <stop offset="0" stop-color="#20b038"></stop>
# <stop offset="1" stop-color="#60d66a"></stop>
# </lineargradient>
# <lineargradient gradientunits="userSpaceOnUse" id="linear-gradient-2" x1="640.25" x2="640.25" y1="746.25" y2="325.49">
# <stop offset="0" stop-color="#f9f9f9"></stop>
# <stop offset="1" stop-color="#fff"></stop>
# </lineargradient>
# </defs>
# <g style="isolation:isolate">
# <g data-name="WhatsApp Logo" id="WhatsApp_Logo">
# <path d="M430.8 746.25l29.59-108A208 208 0 01432.56 534c0-115 93.6-208.49 208.56-208.49a208.59 208.59 0 01208.57 208.64c-.05 115-93.62 208.49-208.57 208.49H641a208.4 208.4 0 01-99.66-25.38zm115.69-66.74l6.33 3.76a173.18 173.18 0 0088.23 24.16h.07c95.55 0 173.31-77.75 173.35-173.3a173.36 173.36 0 00-173.28-173.42c-95.62 0-173.38 77.73-173.42 173.28a172.79 172.79 0 0026.5 92.22l4.13 6.56-17.52 64z" data-name="shape 4" fill="#fff" id="shape_4" transform="translate(-392.93 -292.88)"></path>
# <path d="M23.85 17.55a.45.45 0 110 .9.45.45 0 010-.9zm-5.66-9.408l6.75 3.15a.45.45 0 010 .816l-.641.298.001 3.794a.45.45 0 01-.9 0l-.001-3.374-.899.42v2.525c0 1.552-2.048 2.679-4.5 2.679s-4.5-1.127-4.5-2.68l-.001-2.524-2.44-1.138a.45.45 0 010-.816l6.75-3.15a.45.45 0 01.381 0zm3.41 5.525l-3.6 1.68-3.6-1.68v2.104c0 .91 1.579 1.779 3.6 1.779s3.6-.869 3.6-1.78v-2.103zM18 9.047L12.314 11.7 18 14.353l5.399-2.52.001-.133a.45.45 0 01.017-.124L18 9.046z" fill="#FFF"></path>
# <circle cx="18" cy="33.3" fill="#262637" r="3.2" stroke="#FFF"></circle>
# </g>
# </symbol>
# <symbol id="selected-property-map-pin" viewbox="0 0 34 42">
# <g fill="none" fill-rule="evenodd" transform="translate(-3 1)">
# <path d="M20 33s2.644-2.111 3.886-2.431a15.419 15.419 0 002.914-1.074c5.169-2.522 8.73-7.828 8.73-13.966C35.53 6.953 28.576 0 20 0 11.423 0 4.47 6.953 4.47 15.53c0 6.178 3.609 11.514 8.833 14.015.918.439 1.886.79 2.892 1.044C17.413 30.896 20 33 20 33z" fill="#262637" stroke="#FFF"></path>
# <path d="M14 14.46V21h12v-6.54l-6-5.143-6 5.143zm-.65-.76L20 8l6.65 5.7a1 1 0 01.35.76V21a1 1 0 01-1 1H14a1 1 0 01-1-1v-6.54a1 1 0 01.35-.76z" fill="#FFF"></path>
# <circle cx="20" cy="37" fill="#262637" r="3.5" stroke="#FFF"></circle>
# </g>
# </symbol>
# <symbol id="selected-property-school-map-pin" viewbox="0 0 48 62">
# <g fill="none" fill-rule="evenodd" transform="translate(-6 1)">
# <path d="M30 49.5s3.966-3.167 5.83-3.647a23.128 23.128 0 004.37-1.611c7.753-3.782 13.094-11.741 13.094-20.948C53.294 10.43 42.865 0 30 0S6.706 10.43 6.706 23.294c0 9.268 5.412 17.272 13.249 21.023a23.125 23.125 0 004.338 1.567C26.12 46.344 30 49.5 30 49.5z" fill="#262637" stroke="#FFF"></path>
# <path d="M30 42.75s2.945-2.351 4.328-2.708a17.17 17.17 0 003.245-1.196c5.756-2.808 9.721-8.717 9.721-15.552C47.294 13.743 39.551 6 30 6s-17.294 7.743-17.294 17.294c0 6.88 4.018 12.823 9.836 15.608 1.022.49 2.1.881 3.221 1.163C27.12 40.407 30 42.75 30 42.75z" fill="#262637" stroke="#FFF" stroke-width="2"></path>
# <path d="M21 21.69v9.81h18v-9.81l-9-7.714-9 7.714zm-.976-1.139L30 12l9.976 8.551a1.5 1.5 0 01.524 1.139v9.81A1.5 1.5 0 0139 33H21a1.5 1.5 0 01-1.5-1.5v-9.81a1.5 1.5 0 01.524-1.139z" fill="#FFF"></path>
# <circle cx="30" cy="55.5" fill="#262637" r="5" stroke="#FFF"></circle>
# </g>
# </symbol>
# <symbol id="house" viewbox="0 0 16 16">
# <path d="M0 24V0h1.5v12.438L4.72 9.22a2.25 2.25 0 114.057.009l.004-.009 2.999 3a2.241 2.241 0 011.949.004l-.009-.005 6-5.999a2.25 2.25 0 111.052 1.057l.008.004-6 5.999.043.094a2.25 2.25 0 11-4.146 0l.042-.094-2.999-3a2.23 2.23 0 01-.97.22c-.35 0-.683-.08-.979-.223l.009.004L1.5 14.56v7.94H24V24H0zm12.75-10.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-6-6a.75.75 0 100 1.5.75.75 0 000-1.5zm15-3a.75.75 0 100 1.5.75.75 0 000-1.5z" fill="#111118" fill-rule="evenodd"></path>
# </symbol>
# <symbol id="link" viewbox="0 0 14 14">
# <g fill="#11828D" fill-rule="evenodd">
# <path d="M11.143 13.143V8H12v6H0V2h6v.857H.857v10.286z"></path>
# <path d="M8.342 2.055h3.71v3.71h-.857l-.001-2.247-4.42 4.42-.606-.606 4.42-4.42H8.341v-.857z"></path>
# </g>
# </symbol>
# <symbol id="zoom-in" viewbox="0 0 19 19">
# <path d="M11.875.25a6.875 6.875 0 11-4.4 12.158l-5.6 5.6-.884-.883 5.6-5.6A6.875 6.875 0 0111.875.25zm0 1.25a5.625 5.625 0 100 11.25 5.625 5.625 0 000-11.25zM12.5 4v2.5H15v1.25h-2.5v2.5h-1.25v-2.5h-2.5V6.5h2.5V4h1.25z" fill-rule="evenodd"></path>
# </symbol>
# <symbol id="zoom-out" viewbox="0 0 19 19">
# <path d="M11.875.25a6.875 6.875 0 11-4.4 12.158l-5.6 5.6-.884-.883 5.6-5.6A6.875 6.875 0 0111.875.25zm0 1.25a5.625 5.625 0 100 11.25 5.625 5.625 0 000-11.25zM15 6.5v1.25H8.75V6.5H15z" fill-rule="evenodd"></path>
# ...
# <option value="/property-to-rent/Hu6.html">Houses to rent in HU6</option>
# </optgroup>
# <optgroup label="Offices:">
# <option value="/commercial-property-to-let/Birmingham/offices.html">Offices to Rent in Birmingham</option>
# <option value="/commercial-property-to-let/Bristol/offices.html">Offices to Rent in Bristol</option>
# <option value="/commercial-property-to-let/Glasgow/offices.html">Offices to Rent in Glasgow</option>
# <option value="/commercial-property-to-let/Leeds/offices.html">Offices to Rent in Leeds</option>
# <option value="/commercial-property-to-let/Leicester/offices.html">Offices to Rent in Leicester</option>
# <option value="/commercial-property-to-let/London/offices.html">Offices to Rent in London</option>
# <option value="/commercial-property-to-let/Manchester/offices.html">Offices to Rent in Manchester</option>
# <option value="/commercial-property-to-let/Newcastle-Upon-Tyne/offices.html">Offices to Rent in Newcastle Upon Tyne</option>
# <option value="/commercial-property-to-let/Nottingham/offices.html">Offices to Rent in Nottingham</option>
# <option value="/commercial-property-to-let/Soho/offices.html">Offices to Rent in Soho</option>
# <option value="/commercial-property-to-let/Birmingham/serviced-offices.html">Serviced Offices to Rent in Birmingham</option>
# <option value="/commercial-property-to-let/Bristol/serviced-offices.html">Serviced Offices to Rent in Bristol</option>
# <option value="/commercial-property-to-let/Glasgow/serviced-offices.html">Serviced Offices to Rent in Glasgow</option>
# <option value="/commercial-property-to-let/Leeds/serviced-offices.html">Serviced Offices to Rent in Leeds</option>
# <option value="/commercial-property-to-let/Leicester/serviced-offices.html">Serviced Offices to Rent in Leicester</option>
# <option value="/commercial-property-to-let/London/serviced-offices.html">Serviced Offices to Rent in London</option>
# <option value="/commercial-property-to-let/Manchester/serviced-offices.html">Serviced Offices to Rent in Manchester</option>
# <option value="/commercial-property-to-let/Newcastle-Upon-Tyne/serviced-offices.html">Serviced Offices to Rent in Newcastle Upon Tyne</option>
# <option value="/commercial-property-to-let/Nottingham/serviced-offices.html">Serviced Offices to Rent in Nottingham</option>
# <option value="/commercial-property-to-let/Soho/serviced-offices.html">Serviced Offices to Rent in Soho</option>
# </optgroup>
# </select>
# <div class="no-svg-chevron select-chevron">
# <svg id="core-icon--chevron" viewbox="0 0 7.6 4.1"><path d="M4 4L7.5.5c.2-.2.1-.5-.2-.5h-7C0 0-.1.3.1.5L3.6 4c.1.1.3.1.4 0z"></path></svg>
# </div>
# </div>
# </div>
# </div>
# </div>
# <style>
#
#     .globalFooter *, :after, :before {
#         -webkit-box-sizing: border-box;
#         box-sizing: border-box;
#     }
#
#     .globalFooter button, .globalFooter select {
#         text-transform: none;
#     }
#     .globalFooter button, .globalFooter optgroup, .globalFooter select {
#         color: inherit;
#         font: inherit;
#         margin: 0;
#     }
#     .globalFooter optgroup {
#         font-weight: bold;
#     }
#     .globalFooter h1, .globalFooter h2, .globalFooter h3, .globalFooter h4, .globalFooter h5, .globalFooter h6 {
#         margin: 0;
#         font-size: 15px;
#         font-weight: 400;
#     }
#
#     .globalFooter {
#         line-height: initial;
#         position: relative;
#         width: 100%;
#         padding: 0 15px;
#         background-color: #EAEAEA;
#         -webkit-box-sizing: border-box;
#         box-sizing: border-box;
#     }
#     .globalFooter::after {
#         content: " ";
#         display: table;
#         clear: both; }
#
#     .globalFooter-menu {
#         max-width: 1400px;
#         margin: 0 auto;
#         padding: 0;
#         padding-top: 15px; }
#     .globalFooter-menu::after {
#         content: " ";
#         display: table;
#         clear: both; }
#     @media (min-width: 48em) {
#         .globalFooter-menu {
#             padding-top: 30px; } }
#
#     .globalFooter-menuFooter {
#         display: -webkit-box;
#         display: -webkit-flex;
#         display: -ms-flexbox;
#         display: flex;
#
#         -webkit-flex-direction: column-reverse;
#         flex-direction: column-reverse;
#
#         -webkit-justify-content: space-between;
#         justify-content: space-between;
#
#         max-width: 1400px;
#         margin: 0 auto;
#         border-top: 1px solid #DFDFE1;
#         padding: 15px 0;
#         font-size: 13px;
#     }
#     @media (min-width: 75em) {
#         .globalFooter-menuFooter {
#             padding: 30px 15px;
#
#             -webkit-flex-direction: row-reverse;
#             flex-direction: row-reverse;
#
#             align-items: center;
#             -webkit-align-items: center;
#         }
#     }
#
#     .globalFooter-chevron {
#         pointer-events: none;
#         position: absolute;
#         top: 10px;
#         right: 0;
#         width: 15px;
#         height: 15px;
#         color: #53535F;
#         stroke: transparent; }
#     .globalFooter-menuGroup--expanded .globalFooter-chevron {
#         -webkit-transform: rotate(180deg);
#         -ms-transform: rotate(180deg);
#         transform: rotate(180deg); }
#     @media (min-width: 48em) {
#         .globalFooter-chevron {
#             display: none; } }
#
#     .globalFooter-menuGroup {
#         border-top: 1px solid #DFDFE1;
#         list-style: none; }
#     .globalFooter-menuGroup:nth-child(1) {
#         border-top: none; }
#     @media (min-width: 48em) {
#         .globalFooter-menuGroup {
#             float: left;
#             margin-bottom: 30px;
#             border-top: none;
#             cursor: default; } }
#     @media (min-width: 48em) and (max-width: 74.99em) {
#         .globalFooter-menuGroup {
#             width: 33.33333%; }
#         .globalFooter-menuGroup:nth-child(1n) {
#             border-right: 1px solid #DFDFE1;
#             padding-left: 15px;
#             padding-right: 15px; }
#         .globalFooter-menuGroup:nth-child(3n) {
#             border-right: none; }
#         .globalFooter-menuGroup:nth-child(4n) {
#             clear: left; } }
#     @media (min-width: 75em) {
#         .globalFooter-menuGroup {
#             width: 16.66667%; }
#         .globalFooter-menuGroup:nth-child(n-1) {
#             border-right: 1px solid #DFDFE1;
#             padding-left: 15px;
#             padding-right: 15px; }
#         .globalFooter-menuGroup:nth-child(6) {
#             border-right: none; } }
#
#     .globalFooter-menuGroupHeader {
#         position: relative;
#         padding: 7.5px 0;
#         font-size: 15px;
#         font-family: Effra-Medium, Arial, Geneva, sans-serif;
#         -webkit-font-smoothing: antialiased;
#         font-weight: normal;
#         color: #53535F;
#         cursor: pointer; }
#
#     .globalFooter-menuGroupHeader-checkbox:focus + h4 > label {
#         outline: 5px auto -webkit-focus-ring-color;
#     }
#
#     .globalFooter-subMenu {
#         max-height: 0;
#         padding: 0;
#         overflow: hidden; }
#     .globalFooter-menuGroup--expanded .globalFooter-subMenu {
#         max-height: 500px; }
#     @media (min-width: 48em) {
#         .globalFooter-subMenu {
#             max-height: none; } }
#
#     .globalFooter-subMenuItem {
#         border-top: 1px solid #DFDFE1; }
#     @media (min-width: 48em) {
#         .globalFooter-subMenuItem {
#             border-top: none; } }
#
#     .globalFooter-subMenuItem--secondary {
#         display: inline-block; }
#     @media (min-width: 48em) {
#         .globalFooter-subMenuItem--secondary {
#             display: none; } }
#
#     .globalFooter-subMenuLink {
#         display: block;
#         margin: 4.5px 0;
#         font-size: 15px;
#         text-decoration: none;
#         color: #66636E;
#     }
#     @media (min-width: 48em) {
#         .globalFooter-subMenuLink {
#             padding: 2px 0;
#         }
#     }
#
#     .globalFooter-subMenuItem-black {
#         font-size: 15px;
#         color: #262637; }
#     .globalFooter-subMenuItem-black .globalFooter-subMenuLink {
#         width: 136px;
#         height: 30px;
#         border-radius: 2px;
#         background-color: #262637;
#         font-size: 13px;
#         color: #ffffff;
#         line-height: 27px;
#         text-align: center;
#         margin: 8px 0;
#         line-height: 30px;
#         padding: 0; }
#
#     .globalFooter-cities {
#         display: none; }
#     @media (min-width: 48em) {
#         .globalFooter-cities {
#             display: block; } }
#     @media (min-width: 75em) {
#         .globalFooter-cities {
#             float: left; } }
#
#     .globalFooter-citiesHeader {
#         padding-right: 15px; }
#
#     .globalFooter-citiesSelectWrapper {
#         line-height: initial;
#         display: inline-block;
#         position: relative;
#         border: 1px solid #DFDFE1;
#         padding: 3px 10px;
#         background: #F5F5F5; }
#     .globalFooter-citiesSelectWrapper .select-chevron {
#         right: 10px;
#         width: 12px; }
#
#     .globalFooter-citiesSelect {
#         line-height: initial;
#         color: #262637;
#         font-size: 13px; }
#
#     .globalFooter-legal {
#         width: 100%;
#         line-height: 30px;
#         text-align: center;
#     }
#     @media (min-width: 48em) {
#         .globalFooter-legal {
#             padding: 15px 0;
#             text-align: left;
#         }
#     }
#     @media (min-width: 75em) {
#         .globalFooter-legal {
#             float: right;
#             width: auto;
#             padding: 0;
#             text-align: right;
#         }
#     }
#
#     .globalFooter-legalTitle {
#         display: none;
#         font-weight: 400; }
#     @media (min-width: 48em) {
#         .globalFooter-legalTitle {
#             display: inline-block; } }
#
#     .globalFooter-legalLink {
#         padding: 0 7.5px;
#         text-decoration: none;
#         color: #707070; }
#     @media (min-width: 48em) {
#         .globalFooter-legalLink {
#             margin-left: 15px;
#             border-left: 1px solid #DFDFE1;
#             padding: 0 0 0 15px; } }
#
#     .globalFooter-legalLink--secondary {
#         display: none; }
#     @media (min-width: 48em) {
#         .globalFooter-legalLink--secondary {
#             display: inline-block; } }
#
#     .select {
#         -webkit-appearance: none;
#         -moz-appearance: none;
#         -ms-appearance: none;
#         appearance: none;
#         border-radius: 0;
#         border: none;
#         background: transparent;
#         cursor: pointer; }
#     .select::-ms-expand {
#         display: none; }
#
#     .globalFooter-citiesSelectWrapper .select-chevron {
#         right: 10px;
#         width: 12px;
#     }
#     svg:not(:root) {
#         overflow: hidden;
#     }
#     .select-chevron {
#         width: 9px;
#         height: 9px;
#         margin-left: 2px;
#         pointer-events: none;
#         fill: #797885;
#         stroke: transparent;
#         -webkit-transition-property: fill, -webkit-transform;
#         transition-property: fill, -webkit-transform;
#         transition-property: transform, fill;
#         transition-property: transform, fill, -webkit-transform;
#         -webkit-transition-duration: 0.2s;
#         transition-duration: 0.2s;
#         -webkit-transition-timing-function: ease-in-out;
#         transition-timing-function: ease-in-out;
#         display: inline-block;
#     }
#
#     .globalFooter-menuGroupHeader > label {
#         width: 100%;
#         display: inline-block;
#         font-weight: 400;
#         cursor: pointer; }
#     .globalFooter-menuGroupHeader-checkbox {
#         position: absolute;
#         opacity: 0;
#         z-index: -1; }
#     .globalFooter-menuGroup {
#         position: relative; }
#     .globalFooter-menuGroupHeader-checkbox:checked ~ .globalFooter-subMenu {
#         max-height: 500px; }
#     .globalFooter-menuGroupHeader-checkbox:checked ~ .globalFooter-menuGroupHeader .globalFooter-chevron {
#         -webkit-transform: rotate(180deg);
#         -ms-transform: rotate(180deg);
#         transform: rotate(180deg); }
#
# </style>
# <script type="text/javascript">
#     window.PAGE_MODEL = {"propertyData":{"id":"77411832","status":{"published":true,"archived":false},"text":{"description":"Wedgewood Estates are pleased to offer a very unique opportunity to purchase a large portfolio in the heart of influential Mayfair, London, and comprises of the following outstanding properties ; two charming freehold white stucco buildings, a magnificent seven bedroomed townhouse with lift, plus seven much sought after elite mews houses. <br /><br />One building offers; five recently refurbished 4 x 2 bedroomed apartments + 1 x 3 bedroom duplex apartment with patio.<br /><br />Other building offers; seven luxury lateral apartments 1 x 3 Bedroom + 4 x 2 Bedroom + 1 x Bedroom + a studio flat.<br /><br />The mews houses include and offer; 2 x 2 bedrooms plus 3 x 3 bedrooms plus 2 x 4 bedrooms contemporary properties, five of the mews houses also each benefit with integral garages.","propertyPhrase":"Block of apartments","disclaimer":"<b>Disclaimer</b> - Property reference 2584828. The information displayed about this property comprises a property advertisement. Rightmove.co.uk makes no warranty as to the accuracy or completeness of the advertisement or any linked or associated information, and Rightmove has no control over the content. This property advertisement does not constitute property particulars. The information is provided and maintained by <b>Wedgewood Estates, London</b>. Please contact the selling agent or developer directly to obtain any information which may be available under the terms of The Energy Performance of Buildings (Certificates and Inspections) (England and Wales) Regulations 2007 or the Home Report if in relation to a residential property in Scotland.","auctionFeesDisclaimer":null,"guidePriceDisclaimer":null,"reservePriceDisclaimer":null,"staticMapDisclaimerText":"Map data ©<a href=\"http://www.openstreetmap.org/copyright\" rel=\"nofollow\" target=\"_blank\" title=\"Open Street Map\">OpenStreetMap</a> contributors.","newHomesBrochureDisclaimer":"Please note that Rightmove will send the above details to Wedgewood Estates only. By submitting this form, you confirm that you agree to our website <a href=\"/this-site/terms-of-use.html\">terms of use</a>, our <a href=\"/this-site/privacy-policy.html\">privacy policy</a> and understand how we store <a href=\"/this-site/cookies.html\">cookies</a> on your device.","shareText":"Check out this Block of apartments for sale on Rightmove","shareDescription":"Block of apartments for sale in Investment Opportunity in Mayfair W1J POA. Marketed by Wedgewood Estates, London","pageTitle":"Block of apartments for sale in Investment Opportunity in Mayfair W1J"},"prices":{"primaryPrice":"POA","secondaryPrice":null,"displayPriceQualifier":"","exchangeRate":null},"address":{"displayAddress":"Investment Opportunity in Mayfair W1J","countryCode":"GB","deliveryPointId":1760072},"keyFeatures":["11 FREEHOLD RESIDENTIAL BUILDINGS","11 SEPERATE BVI COMPANIES","INVESTMENT OPPORTUINITY","WEDGEWOOD ESTATES ARE SOLE &amp; EXCLUSIVE AGENT"],"images":[{"url":"https://media.rightmove.co.uk/103k/102385/77411832/102385_2584828_IMG_00_0000.jpeg","caption":null,"resizedImageUrls":{"size135x100":"https://media.rightmove.co.uk/dir/103k/102385/77411832/102385_2584828_IMG_00_0000_max_135x100.jpeg","size476x317":"https://media.rightmove.co.uk/dir/103k/102385/77411832/102385_2584828_IMG_00_0000_max_476x317.jpeg","size656x437":"https://media.rightmove.co.uk/dir/103k/102385/77411832/102385_2584828_IMG_00_0000_max_656x437.jpeg"}},{"url":"https://media.rightmove.co.uk/103k/102385/77411832/102385_2584828_IMG_01_0000.jpeg","caption":null,"resizedImageUrls":{"size135x100":"https://media.rightmove.co.uk/dir/103k/102385/77411832/102385_2584828_IMG_01_0000_max_135x100.jpeg","size476x317":"https://media.rightmove.co.uk/dir/103k/102385/77411832/102385_2584828_IMG_01_0000_max_476x317.jpeg","size656x437":"https://media.rightmove.co.uk/dir/103k/102385/77411832/102385_2584828_IMG_01_0000_max_65 ...
# </script>
# <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[]</script>
# <script async="" data-chunk="shared" src="//media.rightmove.co.uk/assets/a04c507a807f8bdd7543a397a71b0ac4/shared.fbad9c5a8964969509f3.js"></script>
# <div id="scrollbarWidth"></div>
# </body>
# </html>

# %%
name = soup.find('h1', class_ = '_2uQQ3SV0eMHL1P6t5ZDo2q').text
print(name)
# Out:
# Investment Opportunity in Mayfair W1J

# %%
price = soup.find('div', class_ = '_1gfnqJ3Vtd1z40MlC0MzXu').text
print(price)
# Out:
# POA

# %%
propertytype = soup.find('div', class_ = '_1fcftXUEbWfJOJzIUeIHKt').text
print(propertytype)
# Out:
# Block of Apartments

# %%
tenure = soup.find('div', class_ = 'OD0O7FWw1TjbTD4sdRi1_').p
span = tenure.find_next('span').find_next('span')
ten = span.string
print(ten)
# Out:
#  Freehold

# %%
agent_name = soup.find('div', class_ ='fk2DXJdjfI5FItgj0w4Fd').h3.text
print(agent_name)
# Out:
# Wedgewood Estates, London

# %%
agent_address = soup.find('div', class_ = 'fk2DXJdjfI5FItgj0w4Fd').p.text
print(agent_address)
# Out:
# 296 Kensington High Street,
# London,
# W14 8NZ

# %%
contact = soup.find('a', class_ = '_3E1fAHUmQ27HFUFIBdrW0u').text
agent_contact = contact.replace('Call agent:','')
print(agent_contact)
# Out:
#  020 8012 9067

# %%
house ={
    'name': name,
    'price': price,
    'propertytype': propertytype,
    'tenure': ten,
    'agent_name': agent_name,
    'agent_address':agent_address.replace('\r','').replace('\n',''),
    'agent_contact':agent_contact
    
} 
print(house)
# Out:
# {'name': 'One Kensington Gardens, Kensington Road, London W8', 'price': '£16,750,000', 'propertytype': 'Flat', 'tenure': ' Share of Freehold', 'agent_name': 'Strutt & Parker, London - New Homes', 'agent_address': '13 Hill Street,London,W1J 5LQ', 'agent_contact': ' 020 8012 9067'}

# %% [markdown]
# <a id='task6'></a>
# # Task 6: Extracting information of all the products

# %%
houselist = []
for link in productlinks:
    r = requests.get(link, headers = header)
    soup = BeautifulSoup(r.content, 'lxml')
    try: 
        name = soup.find('div', class_ = '_1KCWj_-6e8-7_oJv_prX0H').h1.text
    except: 
        name = 'not given'
    try:
        price = soup.find('div', class_ = '_1gfnqJ3Vtd1z40MlC0MzXu').text
    except: 
        price = 'not given'
    try: 
        propertytype = soup.find('div', class_ = '_1fcftXUEbWfJOJzIUeIHKt').text
    except: 
        propertytype = 'not given'
    try:
        tenure = soup.find('div', class_ = 'OD0O7FWw1TjbTD4sdRi1_').p
        span = tenure.find_next('span').find_next('span')
        ten = span.string
    except: 
        tenure = 'not given'
    
    try: 
        agent_name = soup.find('div', class_ ='fk2DXJdjfI5FItgj0w4Fd').h3.text
    except: 
        agent_name = 'not given'
    try: 
        agent_address = soup.find('div', class_ = 'fk2DXJdjfI5FItgj0w4Fd').p.text
    except: 
        agent_address = 'not given'
    try:
        contact = soup.find('a', class_ = '_3E1fAHUmQ27HFUFIBdrW0u').text
        agent_contact = contact.replace('Call agent:','')
    except: 
        agent_contact = 'not given'
        
    house ={
    'name': name,
    'price': price,
    'propertytype': propertytype,
    'tenure': ten,
    'agent_name': agent_name,
    'agent_address':agent_address.replace('\r',' ').replace('\n',' '),
    'agent_contact':agent_contact
    } 
    houselist.append(house)
    print('Saving:', house['name'])

df = pd.DataFrame(houselist)
# Out:
# Saving: Queens Wharf, 2 Crisp Road, Hammersmith, W6
# Saving: Investment Opportunity in Mayfair W1J
# Saving: Upper Grosvenor Street, London, W1K
# Saving: Upper Grosvenor Street, London, W1K
# Saving: Brook Street, London, W1K
# Saving: Merton Lane, London, N6
# Saving: Merton Lane, London, N6
# Saving: South Street, Mayfair, London, W1K
# Saving: South Street, Mayfair W1K
# Saving: Princes Gate, London, SW7
# Saving: Ilchester Place, Holland Park, London, W14
# Saving: Cleveland Row, St James's, SW1A
# Saving: One Hyde Park, Knightsbridge
# Saving: Upper Phillimore Gardens, Kensington, London, W8
# Saving: Upper Phillimore Gardens, London, W8
# Saving: Culross Street, Mayfair, London, W1K
# Saving: Culross Street, Mayfair, London, W1K
# Saving: Elsworthy Road, London, NW3
# Saving: Phillimore Gardens, Kensington, London
# Saving: Elsworthy Road, Primrose Hill, London, NW3
# Saving: Chapel Street, Belgravia SW1X
# Saving: One Hyde Park, Knightsbridge, London, SW1X
# Saving: St Johns Wood Park, St John's Wood, London, NW8
# Saving: Hamilton Terrace, London, NW8
# Saving: St Johns Wood Park, London, NW8
# Saving: Clova Road, London, E7
# Saving: St Johns Wood Park, St Johns Wood, London, NW8
# Saving: Avenue Road, St. John's Wood, London, NW8
# Saving: Hamilton Terrace, St John's Wood, London, NW8
# Saving: Princes Gate
# Saving: Anhalt Road, Battersea
# Saving: Cambridge Gate, Regent's Park, London, NW1
# Saving: Bedford Gardens, Kensington, London, W8
# Saving: Avenue Road, St. Johns Wood, London, NW8
# Saving: Lancaster Gate, Hyde Park
# Saving: Park Place, St James's, London, SW1A
# Saving: Avenue Road, NW8
# Saving: Cornwall Terrace, London, NW1
# Saving: Lancaster Gate, London, W2
# Saving: The Grande House, St James's, London, SW1A
# Saving: Holland Park, Holland Park, London, W11
# Saving: Hamilton Terrace, St John's Wood, London, NW8
# Saving: Chiltern Street, Marylebone, London, W1U
# Saving: Lennox Gardens, Knightsbridge SW1X
# Saving: Victoria Road, Kensington, London, W8.
# Saving: Chepstow Villas, London, W11
# Saving: Winnington Road, N2
# Saving: One Kensington Gardens, Kensington Road, London W8
# Saving: Hanover Terrace, Regent's Park, London, NW1
# Saving: One Hyde Park, Knightsbridge
# Saving: Aerodrome Road, Hendon, London, NW9
# Saving: St Johns Wood Park, St Johns Wood, London, NW8
# Saving: Avenue Road, St. John's Wood, London, NW8
# Saving: Hamilton Terrace, St John's Wood, London, NW8
# Saving: Princes Gate
# Saving: Anhalt Road, Battersea
# Saving: Cambridge Gate, Regent's Park, London, NW1
# Saving: Bedford Gardens, Kensington, London, W8
# Saving: Avenue Road, St. Johns Wood, London, NW8
# Saving: Lancaster Gate, Hyde Park
# Saving: Park Place, St James's, London, SW1A
# Saving: Avenue Road, NW8
# Saving: Cornwall Terrace, London, NW1
# Saving: Lancaster Gate, London, W2
# Saving: The Grande House, St James's, London, SW1A
# Saving: Holland Park, Holland Park, London, W11
# Saving: Hamilton Terrace, St John's Wood, London, NW8
# Saving: Chiltern Street, Marylebone, London, W1U
# Saving: Lennox Gardens, Knightsbridge SW1X
# Saving: Victoria Road, Kensington, London, W8.
# Saving: Chepstow Villas, London, W11
# Saving: Winnington Road, N2
# Saving: One Kensington Gardens, Kensington Road, London W8
# Saving: Hanover Terrace, Regent's Park, London, NW1
# Saving: One Hyde Park, Knightsbridge
# Saving: Bournemouth Close, London
# Saving: Wilton Mews, London, SW1X
# Saving: Herbert Crescent, Knightsbridge, SW1X
# Saving: Farm Street, Mayfair, London, W1J
# Saving: Farm Street, Mayfair, London, W1J
# Saving: Carlyle Square, London, SW3
# Saving: not given
# Saving: Eglon House, Primrose Hill, London NW1
# Saving: Cornwall Terrace, London
# Saving: Upper Brook Street, Mayfair
# Saving: Lygon Place, London, SW1W
# Saving: Cornwall Terrace, Regent's Park, London, NW1
# Saving: Eglon Mews, London, NW1
# Saving: Totteridge Green, Totteridge, London
# Saving: Grovelands, Totteridge Green, N20
# Saving: Eaton Place, Belgravia, London, SW1X
# Saving: Park Lane, Mayfair, London, W1K
# Saving: Wilton Crescent, Belgravia
# Saving: Fulham Road, Chelsea, London, SW10
# Saving: Cannon Lane, Hampstead Village, NW3
# Saving: Cannon Lane, London, NW3
# Saving: Fulham Road, London, SW10
# Saving: Hamilton Terrace, London, NW8
# Saving: Wilton Crescent, Belgravia, London, SW1X
# Saving: Wilton Crescent &  Kinnerton Street, Belgravia, London, SW1X
# Saving: Pont Street Knightsbridge SW1X
# Saving: Wilton Mews, London, SW1X
# Saving: Herbert Crescent, Knightsbridge, SW1X
# Saving: Farm Street, Mayfair, London, W1J
# Saving: Farm Street, Mayfair, London, W1J
# Saving: Carlyle Square, London, SW3
# Saving: not given
# Saving: Eglon House, Primrose Hill, London NW1
# Saving: Cornwall Terrace, London
# Saving: Upper Brook Street, Mayfair
# Saving: Lygon Place, London, SW1W
# Saving: Cornwall Terrace, Regent's Park, London, NW1
# Saving: Eglon Mews, London, NW1
# Saving: Totteridge Green, Totteridge, London
# Saving: Grovelands, Totteridge Green, N20
# Saving: Eaton Place, Belgravia, London, SW1X
# Saving: Park Lane, Mayfair, London, W1K
# Saving: Wilton Crescent, Belgravia
# Saving: Fulham Road, Chelsea, London, SW10
# Saving: Cannon Lane, Hampstead Village, NW3
# Saving: Cannon Lane, London, NW3
# Saving: Fulham Road, London, SW10
# Saving: Hamilton Terrace, London, NW8
# Saving: Wilton Crescent, Belgravia, London, SW1X
# Saving: Wilton Crescent &  Kinnerton Street, Belgravia, London, SW1X
# Saving: Scott Avenue, West Hill, London, SW15
# Saving: Hamilton Terrace, St John's Wood, London, NW8
# Saving: One Hyde Park, Knightsbridge, London, SW1X
# Saving: Grosvenor Square, Mayfair, London, W1K
# Saving: Grosvenor Square, London, W1K
# Saving: Grosvenor Square, London, W1K
# Saving: Hamilton Terrace, St John's Wood, London NW8
# Saving: Cottesmore Gardens, London, W8
# Saving: Cottesmore Gardens, Kensington, London, W8
# Saving: Chesham Place, London
# Saving: The Sloane Building, Hortensia Road, London, SW10
# Saving: Eaton Square, Belgravia, SW1W
# Saving: Harley Street, Marylebone, London, W1G
# Saving: The Sloane Building, Hortensia Road, Chelsea, London, SW10
# Saving: Sloane Gardens, Belgravia, London, SW1W
# Saving: Eaton Place, London, SW1X
# Saving: Davies Street, London, W1K
# Saving: Queen Anne's Gate, London, SW1H
# Saving: Hanover Terrace, London, NW1
# Saving: Old Queen Street, St. James's Park, London, SW1H
# Saving: Old Queen Street, London, SW1H
# Saving: Lygon Place, Belgravia, London
# Saving: Carlyle Square, Chelsea, London, SW3
# Saving: Lygon Place, Belgravia, London, SW1W
# Saving: Hamilton Terrace, London, NW8
# Saving: Warwick Drive, West Putney, London, SW15
# Saving: Hamilton Terrace, St John's Wood, London, NW8
# Saving: One Hyde Park, Knightsbridge, London, SW1X
# Saving: Grosvenor Square, Mayfair, London, W1K
# Saving: Grosvenor Square, London, W1K
# Saving: Grosvenor Square, London, W1K
# Saving: Hamilton Terrace, St John's Wood, London NW8
# Saving: Cottesmore Gardens, London, W8
# Saving: Cottesmore Gardens, Kensington, London, W8
# Saving: Chesham Place, London
# Saving: The Sloane Building, Hortensia Road, London, SW10
# Saving: Eaton Square, Belgravia, SW1W
# Saving: Harley Street, Marylebone, London, W1G
# Saving: The Sloane Building, Hortensia Road, Chelsea, London, SW10
# Saving: Sloane Gardens, Belgravia, London, SW1W
# Saving: Eaton Place, London, SW1X
# Saving: Davies Street, London, W1K
# Saving: Queen Anne's Gate, London, SW1H
# Saving: Hanover Terrace, London, NW1
# Saving: Old Queen Street, St. James's Park, London, SW1H
# Saving: Old Queen Street, London, SW1H
# Saving: Lygon Place, Belgravia, London
# Saving: Carlyle Square, Chelsea, London, SW3
# Saving: Lygon Place, Belgravia, London, SW1W
# Saving: Hamilton Terrace, London, NW8
# Saving: Trafalgar Road, Greenwich, SE10
# Saving: Marylebone Square, Moxon St, Marylebone, W1U
# Saving: Marylebone Square, Moxon Street, Marylebone, W1
# Saving: Marylebone Square, Marylebone
# Saving: Hamilton Terrace, St John's Wood, London, NW8
# Saving: The Bishops London, N2
# Saving: Stratford Place, London, W1C
# Saving: The Bishops Avenue, London, N2
# Saving: Broomhouse Lane London SW6
# Saving: Courtenay Avenue, London, N6
# Saving: Courtenay Avenue, Highgate, London, N6
# Saving: Cavendish Avenue, St John's Wood, London, NW8
# Saving: Hanover Terrace, London, NW1
# Saving: Cavendish Avenue, St John's Wood, London, NW8
# Saving: One Kensington Gardens, Kensington Road, London W8
# Saving: Hampstead Lane, Hampstead
# Saving: South Street, London, W1K
# Saving: Marylebone Square, Moxon St, W1U
# Saving: Oceanic House, Cockspur Street, London
# Saving: Cockspur Street, London, SW1Y
# Saving: Lancer Square, Kensington Church Street, London, W8
# Saving: Connaught Place, Hyde Park, London, W2
# Saving: Kensington Court, Kensington, London, W8
# Saving: Rarely available freehold investment opportunity consisting of four outstanding apartments
# Saving: Brompton Square, London, SW3
# Saving: Godolphin Road, Shepherd's Bush, London, W12
# Saving: Marylebone Square, Moxon St, Marylebone, W1U
# Saving: Marylebone Square, Moxon Street, Marylebone, W1
# Saving: Marylebone Square, Marylebone
# Saving: Hamilton Terrace, St John's Wood, London, NW8
# Saving: The Bishops London, N2
# Saving: Stratford Place, London, W1C
# Saving: The Bishops Avenue, London, N2
# Saving: Broomhouse Lane London SW6
# Saving: Courtenay Avenue, London, N6
# Saving: Courtenay Avenue, Highgate, London, N6
# Saving: Cavendish Avenue, St John's Wood, London, NW8
# Saving: Hanover Terrace, London, NW1
# Saving: Cavendish Avenue, St John's Wood, London, NW8
# Saving: One Kensington Gardens, Kensington Road, London W8
# Saving: Hampstead Lane, Hampstead
# Saving: South Street, London, W1K
# Saving: Marylebone Square, Moxon St, W1U
# Saving: Oceanic House, Cockspur Street, London
# Saving: Cockspur Street, London, SW1Y
# Saving: Lancer Square, Kensington Church Street, London, W8
# Saving: Connaught Place, Hyde Park, London, W2
# Saving: Kensington Court, Kensington, London, W8
# Saving: Rarely available freehold investment opportunity consisting of four outstanding apartments
# Saving: Brompton Square, London, SW3

# %% [markdown]
# # FINAL DATA

# %%
df
# Out:
#                                                   name        price  \
# 0          Queens Wharf, 2 Crisp Road, Hammersmith, W6   £1,700,000
# 1                Investment Opportunity in Mayfair W1J          POA
# 2                  Upper Grosvenor Street, London, W1K  £54,500,000
# 3                  Upper Grosvenor Street, London, W1K  £54,500,000
# 4                            Brook Street, London, W1K  £46,000,000
# ..                                                 ...          ...
# 220  Lancer Square, Kensington Church Street, Londo...  £16,020,000
# 221             Connaught Place, Hyde Park, London, W2  £15,950,000
# 222           Kensington Court, Kensington, London, W8  £15,500,000
# 223  Rarely available freehold investment opportuni...  £15,500,000
# 224                       Brompton Square, London, SW3  £15,495,000
#
#             propertytype      tenure  \
# 0              Apartment   Leasehold
# 1    Block of Apartments    Freehold
# 2               Terraced    Freehold
# 3             Town House    Freehold
# 4              not given    Freehold
# ..                   ...         ...
# 220            Penthouse   Leasehold
# 221                 Flat   Leasehold
# 222            Apartment    Freehold
# 223             Terraced    Freehold
# 224             Terraced    Freehold
#
#                                             agent_name  \
# 0                         MyLondonHome, Central London
# 1                            Wedgewood Estates, London
# 2                                Knight Frank, Mayfair
# 3                Clifton Property Partners Ltd, London
# 4                                Knight Frank, Mayfair
# ..                                                 ...
# 220                 Savills New Homes, Margaret Street
# 221                            Knight Frank, Hyde Park
# 222             Sotheby's International Realty, London
# 223  Berkeley Lettings & Management Limited, Knight...
# 224                             Savills, Knightsbridge
#
#                                          agent_address   agent_contact
# 0            35   Catherine Place  London  SW1E 6DY      020 8012 5678
# 1        296 Kensington High Street,  London,  W14 8NZ   020 8012 4872
# 2                 120a Mount Street,  London,  W1K 3NN   020 8012 3476
# 3                     3 Hill Street,  London,  W1J 5LB   020 7409 5087
# 4                 120a Mount Street,  London,  W1K 3NN   020 8012 3476
# ..                                                 ...             ...
# 220             33 Margaret Street  London  W1G 0JD      020 8012 0342
# 221                 1  Craven Terrace  London  W2 3QD    020 8012 4409
# 222  77-79 Ebury Street, Belgravia,   London,   SW1...   020 8012 2565
# 223                  45 Pont Street  London  SW1X 0BD    020 3402 4752
# 224               188 Brompton Road,  London,  SW3 1HQ   020 8012 3087
#
# [225 rows x 7 columns]
